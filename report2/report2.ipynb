# %% [markdown]
# # レポート2
#
# ## Requirements
# - python3系
# - MeCab
# - numpy, gensim, mecabのpythonバインディング
# - このノートブックと同じ階層にdataディレクトリを作成し, [こちら](https://www.rondhuit.com/download.html#ldcc) からデータをダウンロードして配置
# - [こちら](http://aial.shiroyagi.co.jp/2017/02/japanese-word2vec-model-builder/) からword2vecモデルを取得して配置
#
# ## ディレクトリ構成
#
# ```
# .
# ├── data
# │   ├── topic-news-5903225.txt
# │   │    ...
# │   └── topic-news-6918105.txt
# ├── latest-ja-word2vec-gensim-model
# │   ├── word2vec.gensim.model
# │   ├── word2vec.gensim.model.syn1neg.npy
# │   └── word2vec.gensim.model.wv.syn0.npy
# └── report2.ipynb
# ```

# %%
from pathlib import Pathb
import numpy as np
from gensim.models.word2vec import Word2Vec
import MeCab

# %%
model = Word2Vec.load('./latest-ja-word2vec-gensim-model/word2vec.gensim.model')

# %%
class Tokenizer:
    @classmethod
    def tokenize(cls, sentence, use_neologd=True, dic_path='/usr/lib/mecab/dic/mecab-ipadic-neologd'):
        if use_neologd:
            option = f'-O wakati -d {dic_path}'
        else:
            option = '-O wakati'
        
        t = MeCab.Tagger(option)
        
        parse_result = t.parse(sentence).replace(' \n', '')
        tokens = parse_result.split(' ')
        return tokens
    
    @classmethod
    def tokenize_and_filter(cls, sentence, use_neologd=True, dic_path='/usr/lib/mecab/dic/mecab-ipadic-neologd', filter_by=["名詞", "動詞", "形容詞", "形容動詞"]):
        if use_neologd:
            option = f'-O chasen -d {dic_path}'
        else:
            option = '-O chasen'
        t = MeCab.Tagger(option)
        
        tokens = []
        
        parse_result = t.parse(sentence)
        morphemes = parse_result.split('\n')[:-2]
        for morph in morphemes:
            surf, _, _, pos, _, _ = morph.split('\t')
            if pos.split('-')[0] in filter_by:
                tokens.append(surf)
        return tokens

# %%
# データ読み込み

def split_line(line):
    """各行を文章に分割する. その際, かぎかっこ中の。では分割しないように注意する"""
    sentences = []
    
    in_quote_count = 0
    tmp = []
    for char in line:
        if char == '。' and in_quote_count == 0:
            tmp.append(char)
            sentences.append(''.join(tmp))
            tmp = []
        elif char == '「' or char == '『':
            in_quote_count += 1
            tmp.append(char)
        elif char == '」' or char == '』':
            in_quote_count -= 1
            tmp.append(char)
        else:
            tmp.append(char)
    return sentences
        

def preprocess(lines):
    """given lines of text, return list of (list of token)"""
    token_seqs = []
    sentences = []
    for line in lines:
        line = line.replace('\n', '')
        
        for sen in split_line(line):

            # 関連記事 or 関連情報以下は無視
            if sen == '【関連情報】' or sen == '【関連記事】':
                break
            # 行が空でないかチェック
            if sen:
                token_seq = Tokenizer.tokenize_and_filter(sen, use_neologd=False)
                token_seqs.append(token_seq)
                sentences.append(sen)
    return token_seqs, sentences


def calc_score(token_seq, target_word, min_word=6):
    score = 0
    ignore_count = 0
    for token in token_seq:
        if token not in model.wv:
            ignore_count += 1
            continue
        score += model.wv.similarity(token, target_word)
    num_token = len(token_seq) - ignore_count
    if num_token >= min_word:
        return score / (len(token_seq) - ignore_count)
    else:
        return 0

# %%
target_word = '怒り'

token_seqs = []
sentences = []

for p in Path('./data').glob('*.txt'):
    with p.open('r') as f:
        lines = f.readlines()
        
        token_seqs_tmp, sentences_tmp = preprocess(lines[3:])
        token_seqs.extend(token_seqs_tmp)
        sentences.extend(sentences_tmp)
        
# 各文章の〇〇度合を測る
result = []
for token_seq, sentence in zip(token_seqs, sentences):
    result.append({
        'sentence': sentence,
        'token_seq': token_seq,
        'score': calc_score(token_seq, target_word, min_word=1)
    })

# scoreの降順にソート
sorted(result, key=lambda k: k['score'], reverse=True)[:10]
# Out:
# [{'sentence': '本当に驚きました。', 'token_seq': ['驚き'], 'score': 0.773547554150178},
#  {'sentence': 'でも不安だ。', 'token_seq': ['不安'], 'score': 0.6254362622572959},
#  {'sentence': 'と大変お怒りの様子。',
#   'token_seq': ['大変', '怒り', '様子'],
#   'score': 0.6157276879175946},
#  {'sentence': 'たまらないね。', 'token_seq': ['たまらない'], 'score': 0.5464817954724311},
#  {'sentence': 'すごく、謝りました。',
#   'token_seq': ['すごく', '謝り'],
#   'score': 0.5382587800835938},
#  {'sentence': '恥を知ってほしいね。',
#   'token_seq': ['恥', '知っ', 'ほしい'],
#   'score': 0.5379403460838145},
#  {'sentence': '不安だらけだ。',
#   'token_seq': ['不安', 'だらけ'],
#   'score': 0.5346223609270333},
#  {'sentence': '正直に、はっきりと聞きます。',
#   'token_seq': ['正直', '聞き'],
#   'score': 0.531903227676507},
#  {'sentence': 'その顛末はいかに——。',
#   'token_seq': ['顛末', '——。'],
#   'score': 0.5109663268328465},
#  {'sentence': '私もごめんなさいって言いますし。',
#   'token_seq': ['私', '言い'],
#   'score': 0.5069577043037405}]

# %%
target_word = '怒り'

token_seqs = []
sentences = []

for p in Path('./data').glob('*.txt'):
    with p.open('r') as f:
        lines = f.readlines()
        
        token_seqs_tmp, sentences_tmp = preprocess(lines[3:])
        token_seqs.extend(token_seqs_tmp)
        sentences.extend(sentences_tmp)
        
# 各文章の〇〇度合を測る
result = []
for token_seq, sentence in zip(token_seqs, sentences):
    result.append({
        'sentence': sentence,
        'token_seq': token_seq,
        'score': calc_score(token_seq, target_word, min_word=6)
    })

# scoreの降順にソート
sorted(result, key=lambda k: k['score'], reverse=True)[:10]
# Out:
# [{'sentence': '思ったこと『あのブスめ！』と、怒り心頭だ。',
#   'token_seq': ['思っ', 'こと', 'ブス', 'め', '怒り', '心頭'],
#   'score': 0.4767247590137995},
#  {'sentence': '菜々緒が杉村太蔵のセクハラ発言に嫌悪の表情。',
#   'token_seq': ['菜', '緒', '杉村', '太蔵', 'セクハラ', '発言', '嫌悪', '表情'],
#   'score': 0.4156870290483231},
#  {'sentence': 'のメンバーは笑いつつも「ひどい」「びっくり」とさんまの発言に異議を唱えた。',
#   'token_seq': ['メンバー', '笑い', 'ひどい', 'びっくり', 'さんま', '発言', '異議', '唱え'],
#   'score': 0.41488492371010827},
#  {'sentence': 'まあ、ファンの方に迷惑をかけてしまったので、心配かけてしまったので、申し訳ないなって。',
#   'token_seq': ['ファン', '方', '迷惑', 'かけ', 'しまっ', '心配', 'かけ', 'しまっ', '申し訳'],
#   'score': 0.41136217118679524},
#  {'sentence': '私たちはGhaddafi（カダフィ）のことを忘れない、安らかに。',
#   'token_seq': ['私', 'たち', 'Ghaddafi', 'カダフィ', 'こと', '忘れ', '安らか'],
#   'score': 0.408436657026593},
#  {'sentence': 'すると、店屋のおじさんが、「おい、ガキ、ちょっと待てや。」とかなり乱暴な口調で私を引き留めました。',
#   'token_seq': ['店屋', 'おじさん', 'ガキ', '待て', '乱暴', '口調', '私', '引き留め'],
#   'score': 0.39957401628787415},
#  {'sentence': 'マツコは即座に「今のセリフちょうだい!」と褒めるくらい、この言葉を気に入ったという。',
#   'token_seq': ['マツコ',
#    '即座',
#    '今',
#    'セリフ',
#    'ちょうだい',
#    '!」',
#    '褒める',
#    '言葉',
#    '気に入っ',
#    'いう'],
#   'score': 0.3953983121067167},
#  {'sentence': 'そういう人が、いつか反省してくれるとありがたいですなぁ。',
#   'token_seq': ['人', 'いつか', '反省', 'し', 'くれる', 'ありがたい'],
#   'score': 0.3787018449096587},
#  {'sentence': 'デヴィ夫人のブログに共感のコメントが殺到。',
#   'token_seq': ['デヴィ', '夫人', 'ブログ', '共感', 'コメント', '殺到'],
#   'score': 0.37548823355629496},
#  {'sentence': '次に気を取り直した有吉が、改めて夏目に「自分とマツコ、どっちがいじりにくい？」と質問を投げたが、夏目は「有吉さん」と返答。',
#   'token_seq': ['気',
#    '取り直し',
#    '有吉',
#    '夏目',
#    '自分',
#    'マツコ',
#    'どっち',
#    'いじり',
#    'にくい',
#    '質問',
#    '投げ',
#    '夏目',
#    '有吉',
#    'さん',
#    '返答'],
#   'score': 0.37478133783503875}]

# %%
target_word = '悲しい'

token_seqs = []
sentences = []

for p in Path('./data').glob('*.txt'):
    with p.open('r') as f:
        lines = f.readlines()
        
        token_seqs_tmp, sentences_tmp = preprocess(lines[3:])
        token_seqs.extend(token_seqs_tmp)
        sentences.extend(sentences_tmp)
        
# 各文章の〇〇度合を測る
result = []
for token_seq, sentence in zip(token_seqs, sentences):
    result.append({
        'sentence': sentence,
        'token_seq': token_seq,
        'score': calc_score(token_seq, target_word, min_word=1)
    })

# scoreの降順にソート
sorted(result, key=lambda k: k['score'], reverse=True)[:10]
# Out:
# [{'sentence': 'たまらないね。', 'token_seq': ['たまらない'], 'score': 0.7413013005825441},
#  {'sentence': '本当に驚きました。', 'token_seq': ['驚き'], 'score': 0.6876717736134687},
#  {'sentence': 'すごく、謝りました。',
#   'token_seq': ['すごく', '謝り'],
#   'score': 0.6828894231943108},
#  {'sentence': 'と冗談で締め括った。',
#   'token_seq': ['冗談', '締め括っ'],
#   'score': 0.600302032664652},
#  {'sentence': '私もごめんなさいって言いますし。',
#   'token_seq': ['私', '言い'],
#   'score': 0.5780926845270912},
#  {'sentence': 'やっちゃっていいです。',
#   'token_seq': ['やっ', 'ちゃっ', 'いい'],
#   'score': 0.5775472536920402},
#  {'sentence': '明石家さんまが心境を語った。',
#   'token_seq': ['明石家', 'さんま', '心境', '語っ'],
#   'score': 0.567050635950566},
#  {'sentence': '明石家さんまが心境を語った。',
#   'token_seq': ['明石家', 'さんま', '心境', '語っ'],
#   'score': 0.567050635950566},
#  {'sentence': '正直に、はっきりと聞きます。',
#   'token_seq': ['正直', '聞き'],
#   'score': 0.5646038056939344},
#  {'sentence': '「おい、誰だ笑ってるの！」。',
#   'token_seq': ['誰', '笑っ', 'てる'],
#   'score': 0.5641643368358754}]

# %%
target_word = '悲しい'

token_seqs = []
sentences = []

for p in Path('./data').glob('*.txt'):
    with p.open('r') as f:
        lines = f.readlines()
        
        token_seqs_tmp, sentences_tmp = preprocess(lines[3:])
        token_seqs.extend(token_seqs_tmp)
        sentences.extend(sentences_tmp)
        
# 各文章の〇〇度合を測る
result = []
for token_seq, sentence in zip(token_seqs, sentences):
    result.append({
        'sentence': sentence,
        'token_seq': token_seq,
        'score': calc_score(token_seq, target_word, min_word=6)
    })

# scoreの降順にソート
sorted(result, key=lambda k: k['score'], reverse=True)[:10]
# Out:
# [{'sentence': 'すると、店屋のおじさんが、「おい、ガキ、ちょっと待てや。」とかなり乱暴な口調で私を引き留めました。',
#   'token_seq': ['店屋', 'おじさん', 'ガキ', '待て', '乱暴', '口調', '私', '引き留め'],
#   'score': 0.4824519317820455},
#  {'sentence': 'マツコは即座に「今のセリフちょうだい!」と褒めるくらい、この言葉を気に入ったという。',
#   'token_seq': ['マツコ',
#    '即座',
#    '今',
#    'セリフ',
#    'ちょうだい',
#    '!」',
#    '褒める',
#    '言葉',
#    '気に入っ',
#    'いう'],
#   'score': 0.48187331631335023},
#  {'sentence': 'CMやってるから）こっちもこっちでコマーシャルやってるんで。',
#   'token_seq': ['やっ', 'てる', 'こっち', 'こっち', 'コマーシャル', 'やっ', 'てる'],
#   'score': 0.47590738270378635},
#  {'sentence': '簡単に言うと、会いたくて会いたくて震える曲です。',
#   'token_seq': ['簡単', '言う', '会い', '会い', '震える', '曲'],
#   'score': 0.43042770075496656},
#  {'sentence': '私は辞めますと言って、秋元先生は辞めなさいと。',
#   'token_seq': ['私', '辞め', '言っ', '秋元', '先生', '辞め', 'なさい'],
#   'score': 0.4275552148569907},
#  {'sentence': 'さらに、SMAPの中居正広に「カズさんと一緒にやったら?」と振られると「カズ！って言ってみたいです」と笑顔で返した。',
#   'token_seq': ['SMAP',
#    '中居',
#    '正広',
#    'カズ',
#    'さん',
#    '一緒',
#    'やっ',
#    '?」',
#    '振ら',
#    'れる',
#    'カズ',
#    '言っ',
#    'みたい',
#    '笑顔',
#    '返し'],
#   'score': 0.4238832256005682},
#  {'sentence': '次に気を取り直した有吉が、改めて夏目に「自分とマツコ、どっちがいじりにくい？」と質問を投げたが、夏目は「有吉さん」と返答。',
#   'token_seq': ['気',
#    '取り直し',
#    '有吉',
#    '夏目',
#    '自分',
#    'マツコ',
#    'どっち',
#    'いじり',
#    'にくい',
#    '質問',
#    '投げ',
#    '夏目',
#    '有吉',
#    'さん',
#    '返答'],
#   'score': 0.4195681603881269},
#  {'sentence': 'そういう人が、いつか反省してくれるとありがたいですなぁ。',
#   'token_seq': ['人', 'いつか', '反省', 'し', 'くれる', 'ありがたい'],
#   'score': 0.4075806482695996},
#  {'sentence': '・【エンタがビタミン♪】怒号飛び交う球場で歌いきった！\u3000ベッキー♪♯の歌手魂がすごい。',
#   'token_seq': ['エンタ',
#    'ビタミン',
#    '♪】',
#    '怒号',
#    '飛び交う',
#    '球場',
#    '歌い',
#    'きっ',
#    'ベッキー',
#    '♪♯',
#    '歌手',
#    '魂',
#    'すごい'],
#   'score': 0.40417288413391117},
#  {'sentence': 'あいつ帽子かぶってサングラスして、すごい自意識過剰だと思う。',
#   'token_seq': ['あいつ', '帽子', 'かぶっ', 'サングラス', 'し', 'すごい', '自意識', '過剰', '思う'],
#   'score': 0.4039890002209144}]

# %%
sorted(token_seqs, key=lambda k: k['score'], reverse=True)
# Out:
# [{'score': 0.7122926801481088, 'token_seq': ['お前', '言う']},
#  {'score': 0.7102390935864061, 'token_seq': ['やっ', 'ちゃっ', 'いい']},
#  {'score': 0.6799907018147473, 'token_seq': ['お前', 'つまらない']},
#  {'score': 0.6307879347704235, 'token_seq': ['やり']},
#  {'score': 0.5945888680821403, 'token_seq': ['プライベート', 'メイサ', '支えれ', 'いい']},
#  {'score': 0.5548862992191734, 'token_seq': ['やっ', 'ください']},
#  {'score': 0.5532956688805051, 'token_seq': ['中略']},
#  {'score': 0.5532956688805051, 'token_seq': ['中略']},
#  {'score': 0.5527532741079644,
#   'token_seq': ['私', '捨てる', '言っ', 'ん', '旦那', 'さん', '食べる', '言い張っ']},
#  {'score': 0.5521035202338793, 'token_seq': ['ためし']},
#  {'score': 0.541222265252075, 'token_seq': ['何', '人', 'やっ', 'ちゃっ', 'いい']},
#  {'score': 0.5346579323959039, 'token_seq': ['本人', '言い']},
#  {'score': 0.5133843321454125,
#   'token_seq': ['絵', 'すごい', 'うまかっ', '頑張っ', '欲しい']},
#  {'score': 0.49976563999205265, 'token_seq': ['嫌', 'やめろ']},
#  {'score': 0.4977297886714571, 'token_seq': ['奴', '好き', 'ん', 'しょうが']},
#  {'score': 0.49355243976815355, 'token_seq': ['みの', 'もん']},
#  {'score': 0.4499263439673673, 'token_seq': ['美', '俺', 'びおれ']},
#  {'score': 0.4396012307711379, 'token_seq': ['ヤバ', 'かっ']},
#  {'score': 0.4292931685964955,
#   'token_seq': ['絵', '丁寧', '可愛', 'いく', '凄く', '好き', '残念']},
#  {'score': 0.42731111413039574,
#   'token_seq': ['誰', '笑っ', 'てる', '顔', '真剣', 'そのもの']},
#  {'score': 0.41510061377999385, 'token_seq': ['違い', 'わかり']},
#  {'score': 0.4101872183342719,
#   'token_seq': ['うまい',
#    '具合',
#    'リズム',
#    '乗れ',
#    '間違っ',
#    '震え',
#    '会え',
#    '嘆い',
#    '負け',
#    'なり']},
#  {'score': 0.3894397609690701, 'token_seq': ['誰', '助け', 'ください']},
#  {'score': 0.3861290695477971,
#   'token_seq': ['簡単', '言う', '会い', '会い', '震える', '曲']},
#  {'score': 0.3818217573347229, 'token_seq': ['ー']},
#  {'score': 0.38140057860197607, 'token_seq': ['ミスキャスト', 'すぎ', '辛い']},
#  {'score': 0.37673015211321687, 'token_seq': ['さんま', 'さん', '嫌い', 'これ']},
#  {'score': 0.37457337499293253,
#   'token_seq': ['言う',
#    '言い',
#    '側',
#    'あっ',
#    'ポリバケツ',
#    '蹴飛ばし',
#    'どこ',
#    '行っ',
#    'しまい',
#    'いい',
#    '歳',
#    '紳士',
#    'ガキ',
#    '呼び止め',
#    'おい',
#    'そりゃ',
#    'ない']},
#  {'score': 0.37118334250788515, 'token_seq': ['店', '真心', 'こもっ', '美味しい', '料理']},
#  {'score': 0.3677469856532775,
#   'token_seq': ['言葉', '使い', '荒い', 'コメント', '俺', 'フラット']},
#  {'score': 0.3667583033952657, 'token_seq': ['今後', 'お願い', '致し']},
#  {'score': 0.3602842190157303,
#   'token_seq': ['お天気',
#    'いい',
#    '朝鮮',
#    '人参',
#    'エキス',
#    '飲ん',
#    '元気',
#    'いっぱい',
#    'デート',
#    '♪」']},
#  {'score': 0.35603879166082325, 'token_seq': ['ひどい', 'テロップ']},
#  {'score': 0.3538353623236711,
#   'token_seq': ['前',
#    '俺',
#    'いじる',
#    'いっ',
#    'こと',
#    'やり玉',
#    '挙げる',
#    'ここ',
#    '有吉',
#    'マツコ',
#    'すごい',
#    '剣幕',
#    '言わ',
#    'いい',
#    '驚く',
#    '語気',
#    '荒く',
#    '否定',
#    'し',
#    '言動',
#    '夏目',
#    '有吉',
#    'さん',
#    '怖い',
#    '漏らす']},
#  {'score': 0.3534991887652867,
#   'token_seq': ['やっ', 'いつか', '仁', 'DNA', '混ざり', '合う']},
#  {'score': 0.353099241430972, 'token_seq': ['若く', '可愛い', '女']},
#  {'score': 0.3461046206772641, 'token_seq': ['結局', '食べ', 'くれ', 'ん']},
#  {'score': 0.34516162673941375, 'token_seq': ['注意', 'し', 'くれ', '良い']},
#  {'score': 0.3445207902603945, 'token_seq': ['仕事', 'ある', '言っ', 'てる', '人']},
#  {'score': 0.34403863940005774,
#   'token_seq': ['絵', 'いい', '原作', '付け', '描い', 'いい', 'の', '思っ']},
#  {'score': 0.3437587148171102, 'token_seq': ['高田', 'いつ', '知っ']},
#  {'score': 0.34338037840494995,
#   'token_seq': ['すごい',
#    'いい',
#    '分から',
#    '態度',
#    '出',
#    'いい',
#    'の',
#    '迷っ',
#    'てる',
#    'ん',
#    '敦',
#    'さん',
#    '土田',
#    'さん',
#    '劇団',
#    'さん',
#    '有吉',
#    'さん',
#    '仕事',
#    'し',
#    'ん',
#    '皆さん',
#    '笑い',
#    '変えよ',
#    'し',
#    '下さっ',
#    'いる',
#    '私',
#    '明るく',
#    '周り',
#    '開き直っ',
#    'てる',
#    'ふう',
#    '思わ',
#    'れ',
#    'しまう',
#    'しれ',
#    'ん',
#    'ファン',
#    '方',
#    '一般',
#    '方',
#    '観',
#    'いる',
#    '暗い',
#    '気持ち',
#    'まま']},
#  {'score': 0.3427478288245751, 'token_seq': ['はるか', 'ちゃん']},
#  {'score': 0.33746901630833026,
#   'token_seq': ['気',
#    '取り直し',
#    '有吉',
#    '夏目',
#    '自分',
#    'マツコ',
#    'どっち',
#    'いじり',
#    'にくい',
#    '質問',
#    '投げ',
#    '夏目',
#    '有吉',
#    'さん',
#    '返答',
#    'たま',
#    '本気',
#    '怒っ',
#    'てる',
#    'こと',
#    'ある',
#    '切り出す',
#    '追い打ち',
#    'かける',
#    'よう',
#    'プロ',
#    '家',
#    '帰っ',
#    'ネチネチ',
#    '思い出し',
#    'てる',
#    'ん',
#    '続け',
#    'ここ',
#    '有吉',
#    'けなし']},
#  {'score': 0.33626599367675364,
#   'token_seq': ['お笑い', '大好き', '言っ', 'オタク', 'レベル']},
#  {'score': 0.3354640578518733,
#   'token_seq': ['フジテレビ', 'バカ', 'すぎる', '番組', '説明', 'ネトウヨ', '書い', 'がる']},
#  {'score': 0.33426041587865735, 'token_seq': ['助け', 'ください']},
#  {'score': 0.33325454114565023, 'token_seq': ['正論', 'すぎ', 'ワロタ']},
#  {'score': 0.33204525548078123,
#   'token_seq': ['流石', 'ネタ', 'これ', 'マジ', '逆', '感心', 'する']},
#  {'score': 0.33069514044392917,
#   'token_seq': ['牡蠣', '食中毒', 'なっ', '言う', '物凄く', '悪い', '症状', '聞こえ']},
#  {'score': 0.3278455182936572, 'token_seq': ['事', '僕', '立場', '言っ', 'いけ']},
#  {'score': 0.32166487402005006, 'token_seq': ['温かく', '見守っ', '頂け', '幸い']},
#  {'score': 0.32158456669701085, 'token_seq': ['おわり']},
#  {'score': 0.32145723941254234,
#   'token_seq': ['知識',
#    'ある',
#    '人',
#    '伝え',
#    '方',
#    'する',
#    '若い',
#    '人',
#    '興味',
#    'もて',
#    'ん',
#    '思う']},
#  {'score': 0.3193916255753446, 'token_seq': ['態度', '悪', 'すぎ', 'ワロタ']},
#  {'score': 0.31666219212555546,
#   'token_seq': ['こ',
#    'みち',
#    '君',
#    '美味しい',
#    '料理',
#    '作っ',
#    'もらい',
#    '感謝',
#    '喜び',
#    '声',
#    '掲載',
#    'し']},
#  {'score': 0.31491582820498065,
#   'token_seq': ['女性', '言う', 'かわいい', '私', '略さ', 'れ', 'いる']},
#  {'score': 0.3148947485081722,
#   'token_seq': ['一',
#    '回',
#    'やり直し',
#    '意味',
#    '物件',
#    '探し',
#    'いる',
#    'ん',
#    'CHINTAI',
#    'し',
#    'CM',
#    'やっ',
#    'てる',
#    'こっち',
#    'こっち',
#    'コマーシャル',
#    'やっ',
#    'てる',
#    'CM',
#    '謝っ',
#    'すごく',
#    '謝り']},
#  {'score': 0.3133965575338929,
#   'token_seq': ['一方',
#    '勝手',
#    '自分',
#    '物差し',
#    '図る',
#    'なっ',
#    '言い',
#    'ん',
#    'カッコ',
#    'いい',
#    '考え方',
#    '大人',
#    '人',
#    'し',
#    '意見',
#    '読む',
#    '小木',
#    '小さい',
#    'わかる',
#    '絶賛',
#    'する',
#    '声',
#    '見',
#    'られ']},
#  {'score': 0.31273330846068537,
#   'token_seq': ['どこ', '違っ', 'たけし', '紳助', 'さん', 'キワ', 'どい', 'マル', '暴', '関係']},
#  {'score': 0.31242645051545054,
#   'token_seq': ['エンタ',
#    'ビタミン',
#    '♪】',
#    '山路',
#    '徹',
#    '品性',
#    '下劣',
#    'ヤツ',
#    '罵っ',
#    '江川',
#    '紹子',
#    '何',
#    'し']},
#  {'score': 0.3116639995382326,
#   'token_seq': ['うれしい',
#    'ソフトバンク',
#    'アイフォーン',
#    '使っ',
#    'い',
#    'ａｕ',
#    '電波',
#    'いい',
#    '聞い',
#    '選ん',
#    '話し']},
#  {'score': 0.30898000651679397, 'token_seq': ['皆様', '大切', '報告']},
#  {'score': 0.30825202971852156, 'token_seq': ['やり方']},
#  {'score': 0.30656948880143786,
#   'token_seq': ['不倫',
#    '不倫',
#    'いう',
#    '付き合っ',
#    'てる',
#    '時',
#    'お互い',
#    'よかっ',
#    'ん',
#    'の',
#    '払う',
#    'の',
#    '本人',
#    '認め',
#    '小松',
#    'さん',
#    '聞く',
#    'ない']},
#  {'score': 0.3059381670513687,
#   'token_seq': ['天使', '思う', 'かわいい', '子役', 'ランキング']},
#  {'score': 0.3053092767910598, 'token_seq': ['体', '辛い']},
#  {'score': 0.3037440243172481,
#   'token_seq': ['今',
#    '出',
#    'いる',
#    '番組',
#    '出',
#    'なる',
#    'の',
#    '番組',
#    '側',
#    '失礼',
#    '迷惑',
#    'かかる',
#    '話',
#    'それぞれ',
#    '番組',
#    '話し合っ',
#    '出',
#    'いい',
#    '言っ',
#    '下さる',
#    '番組',
#    '出さ',
#    'せ',
#    '頂い',
#    '気持ち',
#    '持ちこま',
#    '笑っ',
#    'いい',
#    '出',
#    'いいよっ',
#    '言っ',
#    '頂い',
#    'タモリ',
#    'さん',
#    '話',
#    'さ',
#    'せ',
#    '頂い',
#    '火曜',
#    '曲',
#    'の',
#    '出',
#    'いい',
#    'ふう']},
#  {'score': 0.3037379761637175,
#   'token_seq': ['正直',
#    '聞き',
#    '私',
#    '年収',
#    '4',
#    '千',
#    '万',
#    '円',
#    '以上',
#    '男',
#    '結婚',
#    'し',
#    '思っ',
#    'てる',
#    'ん',
#    '今',
#    '25',
#    '歳',
#    '見た目',
#    '可愛い',
#    '思っ',
#    'て',
#    'スタイル',
#    'いい',
#    '思う',
#    'ん']},
#  {'score': 0.3037281911482651, 'token_seq': ['態度', '話', '分かり', 'やすい']},
#  {'score': 0.30339248917000183, 'token_seq': ['局内', '誰', '気付']},
#  {'score': 0.30268622194705125,
#   'token_seq': ['記事',
#    '私',
#    '負け',
#    '思っ',
#    '判定',
#    '覆り',
#    '申し訳',
#    '思う',
#    '海老',
#    '沼',
#    '選手',
#    'コメント',
#    '私',
#    '勝っ',
#    '以上',
#    '海老',
#    '沼',
#    '良い',
#    '成績',
#    '上げ',
#    '欲しかっ',
#    '銅メダル',
#    '取れ',
#    '嬉しい',
#    'チョ',
#    'コメント',
#    '紹介']},
#  {'score': 0.3025222955122171, 'token_seq': ['牡蠣', 'あたっ', 'ちゃっ', '笑い話', 'なり']},
#  {'score': 0.30086638023541784,
#   'token_seq': ['山内',
#    '私',
#    '一緒',
#    '永尾',
#    'まり',
#    'ちゃん',
#    '子',
#    '一緒',
#    '入れ',
#    'いい',
#    '話',
#    'し',
#    'い',
#    'ん',
#    '私',
#    '順位',
#    'すごい',
#    '良かっ',
#    'ん',
#    '時',
#    'よかっ',
#    'お互い',
#    '話し',
#    'ん',
#    '怪訝',
#    'そう',
#    '顔',
#    '明かし',
#    '高城',
#    '私',
#    'すごい',
#    '順位',
#    '下がっ',
#    'しまっ',
#    '周り',
#    '人',
#    '声',
#    'かけ',
#    'いい',
#    'わから',
#    'みんな',
#    'シーン',
#    '話し',
#    'ところ',
#    '中居',
#    '正広',
#    '生放送',
#    'こと',
#    '告げる',
#    'メンバー',
#    '一斉',
#    '悲鳴',
#    '挙げ',
#    'の']},
#  {'score': 0.3005146807784932,
#   'token_seq': ['マツオスズキ', '違う', '切り口', 'ツイート', '見せる', '芸能人']},
#  {'score': 0.3003815593143252,
#   'token_seq': ['今', 'ゆうこ', '考えれ', '放言', '言える', '様', '発言', '数々']},
#  {'score': 0.30010306511000523,
#   'token_seq': ['知識',
#    '持っ',
#    'い',
#    '伝える',
#    '能力',
#    '無い',
#    '人',
#    '残念',
#    '仕方',
#    '気分',
#    '悪い']},
#  {'score': 0.2986941431667484,
#   'token_seq': ['リスナー',
#    '投稿',
#    'もと',
#    '矢作',
#    '兼',
#    '高橋',
#    'みなみ',
#    '発言',
#    '読み上げる',
#    '当たり前',
#    '当たり前',
#    '何',
#    '言っ',
#    'ん',
#    '子',
#    '一緒',
#    'すん',
#    'なっ',
#    '出せ',
#    'そこ',
#    'そん',
#    'すごい',
#    '選挙',
#    'プレッシャー',
#    'ない',
#    'の',
#    'し',
#    'てん',
#    '子',
#    'たち',
#    'ファン',
#    'やっ',
#    'くれ',
#    'てん',
#    'みんな',
#    '小木',
#    '怒り',
#    'まかせ',
#    'まくし立て']},
#  {'score': 0.29841568628798626, 'token_seq': ['泡', '姫', 'ありえる']},
#  {'score': 0.2974878451930635,
#   'token_seq': ['一方',
#    '何',
#    'クレーム',
#    'つけ',
#    'くる',
#    '奴ら',
#    '正直',
#    '思う',
#    '芸人',
#    '飲み',
#    'まくっ',
#    '死ん',
#    'ほう',
#    'これ',
#    '飲む',
#    '危険',
#    'わかっ',
#    'いい',
#    '?」',
#    '抗議',
#    '団体',
#    '活動',
#    '疑問',
#    '呈する',
#    '書き込み',
#    'み',
#    'られ']},
#  {'score': 0.2963870160536435, 'token_seq': ['上位', '入れる']},
#  {'score': 0.29496714113488404,
#   'token_seq': ['生活',
#    'レベル',
#    '下がっ',
#    '生活',
#    '保護',
#    '貰い',
#    '暮らし',
#    'ほう',
#    'いい',
#    '思う',
#    'ん']},
#  {'score': 0.29370226693100654, 'token_seq': ['鈴木', '京香', 'へそ', '曲げ', '濡れ場']},
#  {'score': 0.2921167603964081, 'token_seq': ['期待', 'ください']},
#  {'score': 0.29054542049612464,
#   'token_seq': ['金持ち',
#    '言える',
#    '正論',
#    '正論',
#    'お前',
#    '言う',
#    '正論',
#    '言っ',
#    'いけ',
#    '類',
#    '話し',
#    '国',
#    '東電',
#    '罪',
#    '重い',
#    'ん',
#    '選択',
#    '天秤',
#    'かけ',
#    'させる',
#    'こと',
#    '大罪',
#    '複雑',
#    '声',
#    'たくさん',
#    'あっ']},
#  {'score': 0.29007081841265137,
#   'token_seq': ['お客', 'さん', '反応', 'やる気', '無', 'さ', '過ぎ']},
#  {'score': 0.28871595493447916,
#   'token_seq': ['親友', 'ギャル', '曽根', 'よる', 'ゆうこ', '恐妻', 'いう']},
#  {'score': 0.28837364059818654,
#   'token_seq': ['放送',
#    'よる',
#    '視聴',
#    '者',
#    '投稿',
#    'つまらない',
#    '言う',
#    '人',
#    '怒り',
#    '感じる',
#    '内容',
#    '出演',
#    '者',
#    'マツコ',
#    '有吉',
#    '夏目',
#    'アナ',
#    '討論',
#    '夏目',
#    'アナ',
#    '合コン',
#    '事',
#    '言わ',
#    'れ',
#    'し',
#    '?」',
#    '質問',
#    '有吉',
#    '木目',
#    '数え',
#    'ろ',
#    '!',
#    '言う',
#    '発言',
#    'マツコ',
#    '即座',
#    '今',
#    'セリフ',
#    'ちょうだい',
#    '!」',
#    '褒める',
#    '言葉',
#    '気に入っ',
#    'いう']},
#  {'score': 0.2881559772686663,
#   'token_seq': ['何', '人', 'せい', 'する', 'バチ', '当たっ', 'ん']},
#  {'score': 0.28770493334913033,
#   'token_seq': ['妄想',
#    '中',
#    '何',
#    '決めつけ',
#    '戦う',
#    '人',
#    '世の中',
#    '入る',
#    '事',
#    '人',
#    'いつか',
#    '反省',
#    'し',
#    'くれる',
#    'ありがたい',
#    '最後',
#    '締め括っ']},
#  {'score': 0.2872597654560602, 'token_seq': ['しょうもない', '男', '付き合っ', 'しまう']},
#  {'score': 0.2866933869710866,
#   'token_seq': ['タモリ', '西島', '話', 'ふら', '性格', '悪い']},
#  {'score': 0.28573208746268,
#   'token_seq': ['週刊',
#    '誌',
#    'テレビ',
#    'ワイドショー',
#    '取り上げる',
#    '必要',
#    'ない',
#    'ん',
#    '僕',
#    '思い',
#    '一番',
#    'くだらない',
#    '話題',
#    'ん',
#    '読ん',
#    'じゃう',
#    '自分',
#    '弱',
#    'さ',
#    'ある']},
#  {'score': 0.28494571765632776,
#   'token_seq': ['記事',
#    'ない',
#    '記事',
#    'なる',
#    '言わ',
#    'れ',
#    '私',
#    '辞め',
#    'いう',
#    '辞め',
#    '得',
#    '私',
#    '辞め',
#    '言っ',
#    '秋元',
#    '先生',
#    '辞め',
#    'なさい',
#    '芸能',
#    '界',
#    '執着心',
#    'ない',
#    '人',
#    'はいり',
#    'ふう',
#    '通り',
#    '思っ']},
#  {'score': 0.2843543681631877,
#   'token_seq': ['今',
#    '可愛く',
#    'なっ',
#    'てる',
#    '子',
#    'ん',
#    '私',
#    'はじめ',
#    '可愛く',
#    '可愛く',
#    'なっ',
#    'き',
#    '続け',
#    '道重',
#    'はじめ',
#    '今',
#    '花',
#    '咲い',
#    'て',
#    '子',
#    'い',
#    '先輩',
#    '保田',
#    '圭',
#    '名前',
#    '挙げる',
#    'キャラ',
#    'ある',
#    'アレ',
#    'アレ',
#    '言い',
#    '放題',
#    'AKB',
#    '48',
#    '話題',
#    '振ら',
#    'れる',
#    'ここ',
#    'すごく',
#    '可愛い',
#    '思う',
#    'ん',
#    '可愛い',
#    '思う',
#    'ん',
#    '私',
#    '選挙',
#    '出',
#    '3',
#    '位',
#    '大島',
#    '優子',
#    'さん',
#    '渡辺',
#    '麻友',
#    'さん',
#    '次',
#    '4',
#    '位',
#    'その他',
#    '見栄',
#    'きっ']},
#  {'score': 0.28429189287812673,
#   'token_seq': ['これ', '渡部', '言い方', '悪かっ', '言い', 'よう', 'ない']},
#  {'score': 0.2824301405195446, 'token_seq': ['今', 'たくさん', '心配', 'おかけ', 'し']},
#  {'score': 0.2810022685950845,
#   'token_seq': ['なか',
#    'AKB',
#    'すごい',
#    '難関',
#    '思う',
#    '比べる',
#    '世界',
#    '違い',
#    '過ぎる',
#    '滑稽',
#    '映る',
#    '頑張っ',
#    '下さい',
#    'いい',
#    '一生懸命',
#    'ひねっ',
#    'こと',
#    '言お',
#    'する',
#    '馬鹿',
#    '露呈',
#    'する',
#    'ん',
#    '一定',
#    '理解',
#    '示す',
#    '意見',
#    '散見',
#    'さ',
#    'れ',
#    '全体',
#    'ダメ',
#    '出し',
#    '声',
#    '大半',
#    '占め',
#    'いる',
#    'よう']},
#  {'score': 0.2800467531822837,
#   'token_seq': ['間', '幸せ', '噛みしめ', '大切', '守っ', 'いき', '思っ', 'おり']},
#  {'score': 0.2799143103237407,
#   'token_seq': ['今',
#    '経験',
#    'する',
#    '気',
#    'まんま',
#    'ん',
#    '人',
#    'いい',
#    '尊敬',
#    'できる',
#    '人',
#    'いい',
#    'ウド',
#    '鈴木',
#    'さん',
#    'ホリケン',
#    'さん',
#    '語り',
#    '名倉',
#    '潤',
#    '人',
#    '捧げ',
#    'いい',
#    '訊か',
#    'れる',
#    '捧げ',
#    '好き',
#    '人',
#    'でき',
#    '手紙',
#    '渡し',
#    'もん',
#    '次',
#    '付き合う',
#    '人',
#    '結婚',
#    'し',
#    '"',
#    '重い',
#    '"',
#    '印象',
#    '残し',
#    '菜',
#    '緒',
#    '手紙',
#    '渡し',
#    '人',
#    '誰',
#    '今',
#    '尋ね',
#    'られる',
#    '中学生',
#    'さん',
#    '明かし',
#    '今年',
#    '3',
#    '月',
#    '熱愛',
#    '報道',
#    '出',
#    '""',
#    '"',
#    '名前',
#    '飛び出し']},
#  {'score': 0.27962219298980806,
#   'token_seq': ['質問', '一つ', 'やっ', '金持ち', '男', '結婚', 'できる']},
#  {'score': 0.27951985031844917,
#   'token_seq': ['最終', '回す', '良かっ', '終わる', 'の', '残念']},
#  {'score': 0.27825732061389613,
#   'token_seq': ['女性',
#    'わかる',
#    'ー',
#    '男',
#    'いる',
#    '確か',
#    '本音',
#    '大体',
#    '合っ',
#    'てる',
#    'ある',
#    'ある',
#    'すぎ',
#    '面白い',
#    '記事',
#    '多く',
#    '共感',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.277709223475162,
#   'token_seq': ['宇多田',
#    '最近',
#    '日本',
#    '風変わり',
#    '名前',
#    '子供',
#    '多い',
#    '絶対',
#    '読め',
#    '名前',
#    '日本語',
#    'っぽく',
#    '名前',
#    'かわいそう',
#    '思う',
#    '親御',
#    'さん',
#    'たち',
#    '愛情',
#    'もっ',
#    '名付け',
#    'ん',
#    'ツイート',
#    '心情',
#    '綴っ']},
#  {'score': 0.27743306384760974,
#   'token_seq': ['逮捕', '後', '信仰', '心', '無い', '言っ', 'いる', '本心', '思う']},
#  {'score': 0.277277041788986,
#   'token_seq': ['数字',
#    'いじっ',
#    'てる',
#    '思え',
#    '辛らつ',
#    '意見',
#    '続き',
#    '感触',
#    '意見',
#    'なかっ']},
#  {'score': 0.2771220601328532,
#   'token_seq': ['対し', 'たけし', '後輩', '接し', '方', '紳助', 'さん', '対照', '的']},
#  {'score': 0.27626272655844214,
#   'token_seq': ['男の子',
#    '困っ',
#    '連絡',
#    '取れ',
#    '取っ',
#    'て',
#    '連絡',
#    '取っ',
#    'て',
#    'なん',
#    'てこ',
#    'する',
#    'の',
#    '言え',
#    'いい',
#    '思い',
#    '私',
#    '切り替え',
#    '前',
#    '進む',
#    'ない',
#    '他',
#    'メンバー',
#    'メッチャ',
#    '優しい',
#    '応援',
#    'し',
#    '下さい',
#    'メール',
#    '電話',
#    'し',
#    '下さい',
#    '夜',
#    'ご飯',
#    '一緒',
#    '食べ',
#    'くれ',
#    'みなさん',
#    'ー',
#    'ちゃん',
#    '北原',
#    '里',
#    '英',
#    'みんな',
#    'こじ',
#    'はる',
#    'さん',
#    '服',
#    'くれ',
#    'し',
#    '小嶋',
#    '服',
#    '貰っ',
#    '着',
#    '方',
#    'いい',
#    '着']},
#  {'score': 0.2752443850478966,
#   'token_seq': ['古い',
#    '感覚',
#    'やっ',
#    'いる',
#    '人',
#    '仕事',
#    'する',
#    'の',
#    'すごい',
#    'ストレス',
#    'これ',
#    '面白い',
#    'わから',
#    'ん',
#    '思う',
#    'こと',
#    'ある']},
#  {'score': 0.2748319438761531,
#   'token_seq': ['食中毒', '言う', '物凄く', '重大', '病気', '聞こえ']},
#  {'score': 0.2741850579786225,
#   'token_seq': ['そこ',
#    'ヤバイ',
#    '問題',
#    'ある',
#    'ん',
#    '僕',
#    'お金',
#    '無くなら',
#    '君',
#    '美し',
#    'さ',
#    'の',
#    '消える',
#    '僕',
#    '収入',
#    '年々',
#    '増える',
#    '君',
#    '毎年',
#    '綺麗',
#    'なる',
#    '事']},
#  {'score': 0.2736585106989342,
#   'token_seq': ['ネット',
#    '掲示板',
#    'ツイッター',
#    '今日',
#    'マツコ',
#    '言っ',
#    '痛快',
#    'すげ',
#    'ーーー',
#    'っ',
#    '歯',
#    '衣',
#    '着せ',
#    '自分',
#    '考え',
#    '述べ',
#    'マツコ',
#    '賞賛',
#    '声',
#    '相次い']},
#  {'score': 0.2723176355917598,
#   'token_seq': ['爆笑',
#    '問題',
#    'はじめ',
#    '伊集院',
#    '光',
#    '博多',
#    '大吉',
#    '共演',
#    '芸人',
#    'これ',
#    '苦笑い',
#    '坂',
#    '大事',
#    '猫',
#    'かわり',
#    'パン',
#    'スト',
#    'くれ',
#    '言っ',
#    'ところ',
#    '会話',
#    '終了',
#    'し',
#    'い',
#    '自分',
#    'すごく',
#    '変',
#    '人',
#    'みたい',
#    '頼む',
#    'ひと言',
#    '返事',
#    'くれ',
#    '次回',
#    '会っ',
#    'とき',
#    '言い',
#    '切実',
#    '思い',
#    '明かし']},
#  {'score': 0.2723114372848989,
#   'token_seq': ['伊集院',
#    'たけし',
#    '大塩',
#    '平八郎',
#    'ん',
#    '言わ',
#    'れ',
#    '日本',
#    '史',
#    'あまり',
#    '詳しく',
#    '伊集院',
#    '春日',
#    '同様',
#    '意味',
#    'わから',
#    'いう',
#    'たけし',
#    'さん',
#    '合っ',
#    'てる',
#    'ん',
#    '空気',
#    '流さ',
#    'れ',
#    '春日',
#    'よう',
#    '何',
#    '言っ',
#    'てる',
#    'ん',
#    'わかり',
#    '言え',
#    '過去',
#    '経験',
#    '明かし']},
#  {'score': 0.2721957445576146,
#   'token_seq': ['心配', 'わたし', '誰', '事', 'エロ', 'い', '目', '見よ', 'わたし', '自由']},
#  {'score': 0.2712721537785773,
#   'token_seq': ['新幹線',
#    '寝',
#    'しまい',
#    'ふとっ',
#    '目',
#    '覚める',
#    '切符',
#    '消え',
#    'い',
#    'ッ',
#    '?',
#    'もん',
#    '盗む',
#    '奴',
#    'おる',
#    'わけ',
#    '思い',
#    '探し',
#    '無い',
#    '仕方',
#    '品川',
#    '駅',
#    'それ',
#    '説明',
#    'する',
#    '切符',
#    '代',
#    '払え',
#    '言わ',
#    'れ',
#    '規則',
#    'いえ',
#    'あなた',
#    '方',
#    '人情',
#    '無い',
#    'の',
#    'ッ',
#    '?',
#    'マニュアル',
#    '人間',
#    'ッキライ',
#    'ーー',
#    '略',
#    '俺',
#    'キセル',
#    'する',
#    'ーーッ',
#    '?',
#    '昔',
#    'JR',
#    '人情',
#    '有っ',
#    '(‾',
#    'ー',
#    '‾)',
#    '残念',
#    '残念',
#    '(‾',
#    'ー',
#    '‾)']},
#  {'score': 0.27121261055824125,
#   'token_seq': ['真央', '暴言', 'ラサール石井', '謝罪', 'する', 'ほとぼり', '冷ます', '疑問', '声']},
#  {'score': 0.27093200421868513, 'token_seq': ['気持ち', '沈み']},
#  {'score': 0.2709022866546838,
#   'token_seq': ['北川',
#    '結婚',
#    '後',
#    '言葉',
#    '言う',
#    '機会',
#    '今',
#    'なかっ',
#    'ん',
#    '場',
#    '借り',
#    '皆さん',
#    '御礼',
#    '申し上げ',
#    'ゆず',
#    'お願い',
#    'し',
#    'メッセージ',
#    '述べ',
#    'マイク',
#    'リスナー',
#    '感謝',
#    '気持ち',
#    '伝え']},
#  {'score': 0.27079647523345923, 'token_seq': ['看板', 'ロゴ', '違う']},
#  {'score': 0.2699539416391318,
#   'token_seq': ['女性',
#    '自身',
#    'コメント',
#    '寄せる',
#    '歌舞伎',
#    '関係',
#    '者',
#    '海老蔵',
#    'さん',
#    '様子見',
#    '教え',
#    '請う',
#    '香川',
#    '自分',
#    '恥',
#    'かい',
#    'いい',
#    '覚悟',
#    '決め',
#    'いる',
#    'よう',
#    '内心',
#    '冷や汗',
#    'もの',
#    '思い',
#    '述べ',
#    'いる']},
#  {'score': 0.26981634419271905,
#   'token_seq': ['ユーザー',
#    'パチンコ',
#    '屋',
#    '働い',
#    '生活',
#    'し',
#    'いる',
#    '発言',
#    '悲しい',
#    'コメント',
#    '一生懸命',
#    '働い',
#    'てる',
#    '人',
#    '事',
#    '悪く',
#    '言っ',
#    'てる',
#    'ん',
#    '伝え',
#    '深夜',
#    '戯言',
#    '思っ',
#    'ください',
#    '添え',
#    'いる']},
#  {'score': 0.26898006718111855, 'token_seq': ['真希', '絵', 'ちゃん', 'テレビ', '出る']},
#  {'score': 0.26881408588583666,
#   'token_seq': ['一方',
#    '辛い',
#    '目',
#    'あっ',
#    'やっ',
#    'られ',
#    '気持ち',
#    '人',
#    '多い',
#    '気晴らし',
#    'する',
#    'いい',
#    'ん',
#    '見舞',
#    '金',
#    '使お',
#    '本人',
#    '自由',
#    '支援',
#    '無くなっ',
#    '自分',
#    '頑張ら',
#    'なら',
#    'わけ',
#    '今',
#    '度',
#    '越さ',
#    '程度',
#    '息抜き',
#    '良い',
#    'ん',
#    '現実',
#    '逃避',
#    'やむなし',
#    '声',
#    '少数',
#    'あっ']},
#  {'score': 0.2684295867580192,
#   'token_seq': ['自分',
#    'やり',
#    'こと',
#    'でき',
#    'なっ',
#    'テレビ',
#    '無理',
#    '思っ',
#    'スパーン',
#    '全部',
#    'やめる',
#    '覚悟',
#    'あり']},
#  {'score': 0.26836188215264156,
#   'token_seq': ['これ',
#    'ネット',
#    '掲示板',
#    '芸人',
#    '酔っ',
#    '自分',
#    '達',
#    '番組',
#    '思い',
#    '語りあう',
#    'の',
#    '楽屋',
#    'やれ',
#    '勘違い',
#    'いい',
#    'ところ',
#    '番組',
#    'み',
#    'バカ',
#    '極み',
#    'もん',
#    '公共',
#    '電波',
#    '使っ',
#    '流す',
#    'マジ',
#    '頭',
#    'おかしい',
#    '思え',
#    '笑え',
#    '不謹慎',
#    'バラエティ',
#    '番組',
#    '打ち切っ',
#    'ほう',
#    'いい',
#    '番組',
#    '企画',
#    '内容',
#    '非難',
#    'する',
#    '声',
#    '相次い']},
#  {'score': 0.2680639125266118,
#   'token_seq': ['音声',
#    'ネット',
#    '掲示板',
#    '紹介',
#    'さ',
#    'れる',
#    'すごい',
#    '臨場',
#    '感',
#    '会場',
#    'ものすごい',
#    '衝撃',
#    '走っ',
#    'こと',
#    '分かる',
#    '誰か',
#    'ゲロ',
#    '吐い',
#    '?',
#    'おえ',
#    'ええ',
#    '聞こえる',
#    '完全',
#    '吐い',
#    'てる',
#    '誰',
#    '死ぬ',
#    'ん',
#    '?」',
#    '尋常',
#    'ない',
#    'ファン',
#    '様子',
#    '驚き',
#    '声',
#    '相次い']},
#  {'score': 0.2680231618670854, 'token_seq': ['体', '痛い']},
#  {'score': 0.26700990828174753,
#   'token_seq': ['私',
#    '署名',
#    'し',
#    '時',
#    '他',
#    '一',
#    '名',
#    'こんなに',
#    '人',
#    'いる',
#    'マイク',
#    'あっ',
#    '私',
#    'マイク',
#    '握れ',
#    '良かっ',
#    'ん',
#    '今',
#    '思っ',
#    'てる']},
#  {'score': 0.2660996905676649,
#   'token_seq': ['松本',
#    'ワイルド',
#    '言う',
#    '返す',
#    '言っ',
#    'やっ',
#    'ぇ',
#    '即答',
#    'し',
#    'みせ',
#    '弱腰',
#    '姿勢',
#    '変わら',
#    'これ',
#    '見',
#    '三村',
#    'マサ',
#    'カズ',
#    'ワイルド',
#    'ん',
#    '尋ねる',
#    'ワイルド',
#    '嫌わ',
#    'れ',
#    'ん',
#    '本音',
#    '吐露',
#    'し',
#    'スギ',
#    'ちゃん',
#    '報酬',
#    '額',
#    '結局',
#    '0',
#    '円']},
#  {'score': 0.266041391049159,
#   'token_seq': ['私',
#    '凄く',
#    '怒っ',
#    '韓国',
#    '来',
#    '自分',
#    '言い聞かせ',
#    'ケニア',
#    'いる',
#    '私',
#    '叔母',
#    'あなた',
#    '韓国',
#    '戻っ',
#    '頭',
#    'おかしく',
#    'なる',
#    '言わ',
#    'れ']},
#  {'score': 0.266022822808343,
#   'token_seq': ['登場', '人物', '確か', 'かわいい', '絵', 'きれい']},
#  {'score': 0.265801006590299, 'token_seq': ['毒', 'ある', 'ユーモア', '忘れ', 'い']},
#  {'score': 0.2652667506771784,
#   'token_seq': ['喜ばしい', '事', '韓国', '嫌い', '方々', 'どこ', '韓国', '推す', 'ん']},
#  {'score': 0.26372549608308243,
#   'token_seq': ['買い物',
#    '間違え',
#    'サイダー',
#    '買っ',
#    'き',
#    '夫',
#    'めちゃめちゃ',
#    'キレ',
#    '怒っ',
#    'の']},
#  {'score': 0.2630987006912523,
#   'token_seq': ['ネット',
#    '上',
#    '昨年',
#    'あたり',
#    '西野',
#    'カナ',
#    '歌詞',
#    'ワンパターン',
#    'すぎる',
#    'こと',
#    '話題',
#    'なっ',
#    'おり',
#    'どん',
#    '会い',
#    'ん',
#    '会う',
#    '気',
#    'ない',
#    'ん',
#    '?」',
#    '批判',
#    'あっ']},
#  {'score': 0.2627923298920737,
#   'token_seq': ['一番',
#    '高価',
#    'もの',
#    '買い',
#    '語っ',
#    '夏目',
#    '退社',
#    '時',
#    '心境',
#    'もの',
#    'こと',
#    'うかがわ',
#    'せ',
#    '放送',
#    '直後',
#    'ツイッター',
#    'ネット',
#    '掲示板',
#    '発言',
#    '聴け',
#    '満足',
#    'いい',
#    '夏目',
#    'ちゃん',
#    '!」「',
#    'いい',
#    '買っ',
#    'ちまえ',
#    'バー',
#    'キン',
#    '買っ',
#    'いい',
#    'マジ',
#    '疲れ',
#    '夏目',
#    'ちゃん',
#    '強い',
#    '彼女',
#    'エール',
#    '相次い']},
#  {'score': 0.26263046349733965, 'token_seq': ['意地', '悪い', '週刊', '誌']},
#  {'score': 0.26225511926069917,
#   'token_seq': ['内容',
#    '岡村',
#    'トミーズ',
#    '雅',
#    'ネタ',
#    'ない',
#    'の',
#    '切り出し',
#    '相方',
#    '矢部',
#    'トミーズ',
#    'ネタ',
#    'わかっ',
#    'やっ',
#    'てる',
#    'の',
#    '首',
#    '傾げ']},
#  {'score': 0.26186942754187076,
#   'token_seq': ['これ',
#    '岡村',
#    '隆史',
#    '矢部',
#    '浩之',
#    'とんでも',
#    'ガセ',
#    'ネタ',
#    '全国ネット',
#    '流し',
#    'しまっ',
#    '残念',
#    '申し訳',
#    '謝罪',
#    'し']},
#  {'score': 0.26158509939504615, 'token_seq': ['TBS', '朝', 'ズバッ', 'みの', 'もん']},
#  {'score': 0.2611232006236173,
#   'token_seq': ['有吉',
#    '夏目',
#    '自分',
#    '褒美',
#    'あげ',
#    'こと',
#    'ある',
#    '?」',
#    '何気なく',
#    '質問',
#    'する',
#    '夏目',
#    '意味',
#    '深',
#    '笑み',
#    '浮かべ',
#    'まま',
#    '言い',
#    'づら',
#    'そう',
#    'し',
#    '会社',
#    '辞め',
#    'とき',
#    '明かし',
#    'の']},
#  {'score': 0.2611024603235121,
#   'token_seq': ['わたし',
#    '恋人',
#    'でき',
#    'ちゃーん',
#    'みんな',
#    '報告',
#    'する',
#    'わたし',
#    '絶対',
#    'みんな',
#    '嘘',
#    'つか',
#    'ファン',
#    '向け',
#    'メッセージ',
#    '送っ']},
#  {'score': 0.26103676432306233,
#   'token_seq': ['お客', 'さん', '提供', 'し', 'いる', 'の', '良い', '思い']},
#  {'score': 0.2602114184447364,
#   'token_seq': ['私', '決意', 'AV', '撮影', '皆さん', '見守っ', 'もらい', '思っ', 'い']},
#  {'score': 0.2600803707960501,
#   'token_seq': ['みの',
#    'もん',
#    '引退',
#    '真実味',
#    '東',
#    'スポ',
#    '独占',
#    '直撃',
#    '本当',
#    '激',
#    '白']},
#  {'score': 0.25996288402007695,
#   'token_seq': ['要約', 'する', '作っ', '人', '気持ち', '解ら']},
#  {'score': 0.25948285004782373,
#   'token_seq': ['いま',
#    '巷',
#    '西野',
#    'カナ',
#    'ゲーム',
#    'なる',
#    'もの',
#    '流行',
#    'し',
#    'てる',
#    'いう']},
#  {'score': 0.259482009774756,
#   'token_seq': ['エンタ',
#    'ビタミン',
#    '♪】『',
#    'ひな壇',
#    '芸人',
#    'たけし',
#    '警告',
#    'タモリ',
#    '紳助',
#    '引っ張り',
#    '降ろせ']},
#  {'score': 0.2592982624648672,
#   'token_seq': ['飲み', 'すぎ', '翌日', '韓国', 'のり', '朝', 'ごはん', 'まいっ', '♪」']},
#  {'score': 0.25926256085363053,
#   'token_seq': ['高田',
#    '安め',
#    'ぐみ',
#    '知っ',
#    '読ん',
#    '安め',
#    'ぐみ',
#    '事務所',
#    '社長',
#    'モーニング',
#    '娘',
#    'マネージャー',
#    '和田',
#    '薫',
#    '氏',
#    'お前',
#    '芸風',
#    '嫌い',
#    'ん']},
#  {'score': 0.2588427105000345,
#   'token_seq': ['ドラマ',
#    'でき',
#    'ドラマ',
#    'なっ',
#    'て',
#    '選挙',
#    '4',
#    '位',
#    '本当',
#    'そう',
#    '調子',
#    'のる',
#    'よく',
#    'ん',
#    '調子',
#    'のっ',
#    'て',
#    'みんな',
#    '言っ',
#    'くれる',
#    '大丈夫',
#    '変わり']},
#  {'score': 0.2585572672263045,
#   'token_seq': ['番組',
#    '内',
#    '夕刊',
#    '紙',
#    '紹介',
#    'する',
#    'コーナー',
#    '5',
#    '時',
#    '夢中',
#    '記事',
#    'マツコ',
#    '遠慮なく',
#    '言及',
#    'MC',
#    '逸見',
#    '太郎',
#    'マ',
#    '◯',
#    'コ',
#    '言っ',
#    'いけ',
#    'ん',
#    '聞き',
#    'ダメ',
#    'ん',
#    '返答',
#    'もらう',
#    'マツコ',
#    '舌鋒',
#    'ヒートアップ']},
#  {'score': 0.2584244551088686,
#   'token_seq': ['そ',
#    'こと',
#    'あり',
#    '渡部',
#    'プレイボーイ',
#    'そう',
#    'ISSA',
#    'ふっ',
#    'み',
#    '俺',
#    '最初',
#    '会っ',
#    'とき',
#    'わかり',
#    'もん',
#    '余裕',
#    '発言']},
#  {'score': 0.2578689254897259,
#   'token_seq': ['これ',
#    'ネット',
#    '掲示板',
#    'バカ',
#    'っぽく',
#    '見える',
#    '発言',
#    'する',
#    'ん',
#    'ww',
#    '古典',
#    '芸能',
#    '見',
#    '台本',
#    '古',
#    'すぎる',
#    '意味',
#    '分から',
#    '歌舞伎',
#    'ある',
#    '文楽',
#    'いら',
#    '儲から',
#    'もの',
#    'いら',
#    '思っ',
#    'てる',
#    'ん',
#    '橋',
#    '下',
#    '氏',
#    '非難',
#    '相次い']},
#  {'score': 0.2573767341086303,
#   'token_seq': ['一方',
#    '終わっ',
#    '有吉',
#    'なん',
#    '芸',
#    'ない',
#    '奴',
#    '偉',
#    'そう',
#    '有吉',
#    'みたい',
#    '人',
#    '悪口',
#    '言わ',
#    '奴',
#    '言わ',
#    'れ',
#    '説得',
#    '力',
#    '無い',
#    'こと',
#    '言っ',
#    'つまんなかっ',
#    'とき',
#    '保険',
#    'かけ',
#    'とく',
#    'の',
#    '批判',
#    'コメント',
#    '見',
#    'られ',
#    'キレ',
#    'ある',
#    '毒舌',
#    '魅力',
#    '有吉',
#    '今回',
#    '注目',
#    '集める',
#    '結果',
#    'なっ']},
#  {'score': 0.25715935441278104,
#   'token_seq': ['女性',
#    '叩き',
#    'あまり',
#    '加熱',
#    'っぷり',
#    '病気',
#    'いい',
#    'すぎ',
#    '思っ',
#    '確か',
#    'ここ',
#    '見',
#    'てる',
#    '病気',
#    '近い',
#    'ここ',
#    '女',
#    '憎い',
#    'もん',
#    '呆れ',
#    '声',
#    '一部',
#    'あっ',
#    '毎度',
#    'おごら',
#    'さ',
#    'れる',
#    '彼女',
#    'いら',
#    'の',
#    'ネット',
#    'ユーザー',
#    'たち',
#    '本音',
#    'よう']},
#  {'score': 0.2560012649093208,
#   'token_seq': ['これ',
#    'ネット',
#    '掲示板',
#    '自分',
#    '結婚',
#    'し',
#    'の',
#    '賞味',
#    '期限切れ',
#    'こと',
#    '西川',
#    '厳しい',
#    '声',
#    'あっ',
#    '西川',
#    '言っ',
#    'てる',
#    'こと',
#    '正論',
#    '長谷川',
#    '理恵',
#    '石田',
#    '純一',
#    'カノ',
#    '飯',
#    '食い',
#    'すぎ',
#    '私生活',
#    '切り売り',
#    '必死',
#    'すぎる',
#    '昔',
#    '男',
#    'たち',
#    'いい',
#    '旦那',
#    'グチ',
#    '言う',
#    'の',
#    '酷い',
#    '俺',
#    '旦那',
#    'ブチ',
#    '切れ',
#    '別れる',
#    '長谷川',
#    '暴露',
#    'バッシング',
#    '多く',
#    '見',
#    'られ']},
#  {'score': 0.2546274349711801,
#   'token_seq': ['夏目',
#    '退職',
#    '理由',
#    '変わり',
#    '強い',
#    '思い',
#    'の',
#    '本音',
#    '気',
#    'なる',
#    'ところ']},
#  {'score': 0.2543144387141128, 'token_seq': ['共感', '消費', '耳慣れ', '言葉', '飛び出し']},
#  {'score': 0.25414273051149505,
#   'token_seq': ['こども',
#    'おもちゃ',
#    '紗',
#    '南',
#    'ちゃん',
#    'ぼく',
#    '春名',
#    '風花',
#    'やら',
#    'せ',
#    'ください',
#    '(',
#    '玲',
#    'くん',
#    'ぼく',
#    '事務所',
#    'つけ',
#    'めん',
#    'マネージャー',
#    '風花',
#    '熊田',
#    '聖',
#    '亜',
#    'ちゃん',
#    '澄',
#    'くん',
#    '濱田',
#    '龍',
#    '臣',
#    'くん',
#    '羽山',
#    '根岸',
#    '泰樹',
#    'くん',
#    'いい',
#    '(',
#    'えらい',
#    '人',
#    'バルサン',
#    '希望']},
#  {'score': 0.2541059506314105,
#   'token_seq': ['踏ん切り',
#    'つい',
#    '前向き',
#    '考え',
#    'い',
#    'し',
#    'いる',
#    'ファン',
#    '方',
#    '迷惑',
#    'かけ',
#    'しまっ',
#    '心配',
#    'かけ',
#    'しまっ',
#    '申し訳']},
#  {'score': 0.2539151540863567,
#   'token_seq': ['和田',
#    'アキ子',
#    'キレ',
#    '相手',
#    '秋葉原',
#    'ツンデレカフェ',
#    'メイド',
#    'ツンデレカフェ',
#    '普段',
#    'そっけ',
#    '態度',
#    '発言',
#    'する',
#    'くせ',
#    '2',
#    '人',
#    'なる',
#    'デレデレ',
#    '甘え',
#    'くる',
#    'ツンデレ',
#    'メイド',
#    '店員',
#    'カフェ',
#    'こと']},
#  {'score': 0.2534241368874947,
#   'token_seq': ['ネット',
#    '掲示板',
#    '嫁',
#    '怖い',
#    '?',
#    '嫁',
#    'せい',
#    'する',
#    'w',
#    '逃げ道',
#    '用意',
#    'し',
#    'かかっ',
#    'き',
#    'オカン',
#    'ネタ',
#    'トーク',
#    '本',
#    '稼い',
#    'くせ',
#    '割',
#    '河本',
#    '豪遊',
#    'し',
#    'いる',
#    '矛盾',
#    'コメント',
#    '中',
#    'ネット',
#    '匿名',
#    '綺麗事',
#    '言える',
#    'たいがい',
#    '奴',
#    '嫁',
#    '言わ',
#    'れ',
#    '親',
#    '金',
#    '出し',
#    'にくい',
#    '河本',
#    '同情',
#    'する',
#    '声',
#    '見',
#    'られ']},
#  {'score': 0.2533102158065853, 'token_seq': ['速く', '動け']},
#  {'score': 0.25284628812808113,
#   'token_seq': ['メンバー',
#    '離れ',
#    'ちゃう',
#    '嫌',
#    'ん',
#    'そこ',
#    'AKB',
#    'HKT',
#    '比べ',
#    'AKB',
#    '方',
#    '今',
#    '仲間',
#    '大好き',
#    '気持ち',
#    '強い',
#    '活動',
#    'し',
#    'いく',
#    'うち',
#    'HKT',
#    '大好き',
#    '言える',
#    'よう',
#    '思っ']},
#  {'score': 0.25217070137170133,
#   'token_seq': ['芸人',
#    '酒',
#    '飲ま',
#    'せ',
#    'ぶっ',
#    'けさ',
#    'せる',
#    '企画',
#    '賛否',
#    '両論',
#    'ある',
#    'しれ',
#    '意外',
#    '本音',
#    '垣間見',
#    'え',
#    '一瞬']},
#  {'score': 0.2520341718432694,
#   'token_seq': ['カダフィー', '最後', '言葉', 'マイク', '私', '髪型', 'だい']},
#  {'score': 0.25186224495529425,
#   'token_seq': ['エンタ',
#    'ビタミン',
#    '♪】「',
#    'しゃべり',
#    '過ぎ',
#    'のろけ',
#    'まくる',
#    '菜',
#    '緒',
#    '西川',
#    '貴',
#    '教',
#    'ファン',
#    '怒り',
#    'コメント',
#    'livedoor',
#    'ニュース']},
#  {'score': 0.2507699569090549,
#   'token_seq': ['吉村',
#    '炎上',
#    'し',
#    'ちゃっ',
#    'ん',
#    '喧嘩',
#    '上手',
#    '僕',
#    '喧嘩',
#    '上手',
#    '炎上',
#    'さ',
#    'せ',
#    'ブログ',
#    'コメント',
#    '欄',
#    'ない',
#    'ジョーク',
#    '話',
#    '結ん']},
#  {'score': 0.25006024586372705,
#   'token_seq': ['正論', '言っ', 'てる', 'の', '説得', '力', '損なっ', 'いる']},
#  {'score': 0.2496009549063879,
#   'token_seq': ['記者',
#    '言葉',
#    '問題',
#    '大丈夫',
#    '?」',
#    '質問',
#    'ファーガソン',
#    '監督',
#    '言っ',
#    'いる',
#    'こと',
#    '分から',
#    '英語',
#    '頑張っ',
#    'いる',
#    '監督',
#    '言う',
#    'こと',
#    '理解',
#    'する',
#    '時間',
#    'かかり',
#    'そう',
#    '答え',
#    'いる']},
#  {'score': 0.2492261593848719,
#   'token_seq': ['ツイート',
#    '知っ',
#    '有吉',
#    '仕事',
#    '合間',
#    '立ち寄っ',
#    '薬屋',
#    'クソバイト',
#    'ツイッター',
#    '悪口',
#    '言っ',
#    'て',
#    '報告',
#    'あり',
#    '思っ',
#    'こと',
#    'ブス',
#    'め',
#    '怒り',
#    '心頭']},
#  {'score': 0.24888476928516498,
#   'token_seq': ['東',
#    'うっかり',
#    'し',
#    'て',
#    'お伝え',
#    'する',
#    'の',
#    '忘れ',
#    'ちゃっ',
#    'ん',
#    '笑']},
#  {'score': 0.24855682780962574,
#   'token_seq': ['問題',
#    'フライパン',
#    '買い',
#    '来る',
#    'お客様',
#    '子供',
#    '靴',
#    '買い上げ',
#    'いただく',
#    'あなた',
#    'し',
#    'もの']},
#  {'score': 0.2484854211085707,
#   'token_seq': ['二', '重', '喜び', '私', '自身', '幸せ', '感じ', '責任', '感じ', 'おり']},
#  {'score': 0.24825877314978145,
#   'token_seq': ['牧瀬', 'みさの', '私', 'ＡＶ', '女優', 'なり']},
#  {'score': 0.24798210637749576,
#   'token_seq': ['ネット',
#    '掲示板',
#    'ツイッター',
#    'スタジオ',
#    'どん',
#    '引き',
#    'これ',
#    'ひどい',
#    'テレビ',
#    'やる',
#    '思わ',
#    'かっ',
#    '奴',
#    '驚き',
#    '隠せ',
#    'コメント',
#    '続出',
#    'し',
#    'いる']},
#  {'score': 0.24793094516386885,
#   'token_seq': ['ネット',
#    '掲示板',
#    '男',
#    'ダメ',
#    '返す',
#    '言葉',
#    'ない',
#    'これ',
#    '菜',
#    '緒',
#    '正しい',
#    '菜',
#    '緒',
#    '対応',
#    '支持',
#    'する',
#    'ユーザー',
#    '多かっ']},
#  {'score': 0.2463685342984937,
#   'token_seq': ['放送',
#    '直後',
#    'ツイッター',
#    'いい',
#    '出',
#    'れ',
#    '不憫',
#    'すぎる',
#    'パンクブーブー',
#    'いい',
#    'とも',
#    'そりゃ',
#    'ない',
#    '金',
#    '総',
#    '書記',
#    '不運',
#    '世間',
#    'ニュース',
#    '合わせ',
#    'て',
#    '思う',
#    'パンクブーブー',
#    '同情',
#    '声',
#    '相次い']},
#  {'score': 0.24497084356648746, 'token_seq': ['黄', '熊', 'ぷう']},
#  {'score': 0.24450646340426888,
#   'token_seq': ['升野',
#    'バーター',
#    '批判',
#    'いい',
#    '本人',
#    'バーター',
#    '知ら',
#    '反応',
#    '多かっ',
#    '有吉',
#    '弘行',
#    '升野',
#    '同調',
#    'バーター',
#    '恥ずかしい',
#    '思い',
#    'し',
#    'ほしい',
#    'バーター',
#    'バーター',
#    '顔',
#    'し',
#    'てる',
#    'の',
#    '恥ずかしい',
#    '主張',
#    'し',
#    'いる']},
#  {'score': 0.24416981949648864,
#   'token_seq': ['若い',
#    'の',
#    '苦労',
#    '顔',
#    '出',
#    'てる',
#    '生き',
#    'て',
#    'よかっ',
#    '今度',
#    '普通',
#    '暮らせよ',
#    '何',
#    '回',
#    '目',
#    '復帰',
#    'なる',
#    'ん',
#    '?',
#    '加護',
#    '芸能',
#    '界',
#    'やめ',
#    'ほう',
#    'いい',
#    '気',
#    'する',
#    'ボロボロ',
#    'なる',
#    '過酷',
#    '人生',
#    '歩む',
#    '加護',
#    '心配',
#    'し',
#    '応援',
#    'する',
#    'ネット',
#    'ユーザー',
#    '多く',
#    '加護',
#    '根強い',
#    '人気',
#    'うかがえ']},
#  {'score': 0.2441497520684882,
#   'token_seq': ['ネット',
#    '掲示板',
#    'こいつ',
#    '自分',
#    '酔っ',
#    'ん',
#    '思っ',
#    '言い訳',
#    'し',
#    '謝る',
#    '読売新聞',
#    '記者',
#    '批判',
#    '殺到',
#    'もん',
#    'ひる',
#    'ん',
#    'いじめ',
#    '原因',
#    'わから',
#    '記者',
#    '行動',
#    '疑問',
#    '呈する',
#    '声',
#    '多数',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.24382802490002495,
#   'token_seq': ['開き直っ',
#    'いる',
#    'わけ',
#    'ん',
#    '開き直っ',
#    'ネタ',
#    'する',
#    'の',
#    '変',
#    '話',
#    'ん',
#    'それ',
#    '笑い',
#    '変え',
#    '下さっ',
#    'いる',
#    '笑い',
#    '変え',
#    '謝罪',
#    'する',
#    '番組',
#    'し',
#    'ディレクター',
#    'さん',
#    'プロデューサー',
#    'さん',
#    '話',
#    'し',
#    '謝罪',
#    'なし',
#    '明るく',
#    '行っ',
#    '下さい',
#    '言わ',
#    'れ',
#    'する',
#    'ない']},
#  {'score': 0.24353371775294716,
#   'token_seq': ['結果',
#    '上',
#    '世代',
#    '女性',
#    'てい',
#    'いい',
#    '若者',
#    '男性',
#    '叩き',
#    '言葉',
#    '与え',
#    'しまっ',
#    '反省',
#    'あり',
#    '申し訳',
#    '思っ',
#    'い',
#    '語っ',
#    'いる']},
#  {'score': 0.2429579945667367,
#   'token_seq': ['番組',
#    '中',
#    '光井',
#    '話し',
#    'いる',
#    '最中',
#    'さんま',
#    '唐突',
#    '光井',
#    '尻',
#    '穴',
#    'みたい',
#    '顔',
#    '振っ',
#    'これ',
#    '聞い',
#    'ほか',
#    'モーニング',
#    '娘',
#    'メンバー',
#    '笑い',
#    'ひどい',
#    'びっくり',
#    'さんま',
#    '発言',
#    '異議',
#    '唱え',
#    'あと',
#    'さんま',
#    '弁解',
#    'する',
#    'よう',
#    '可愛い',
#    'ほんま',
#    'ハーフ',
#    'みたい',
#    '顔',
#    'フォロー',
#    'し',
#    'いる']},
#  {'score': 0.24276634053546675,
#   'token_seq': ['私',
#    'メディア',
#    '顔出し',
#    'する',
#    'よう',
#    'なっ',
#    'もて',
#    '中',
#    '年女',
#    '深澤',
#    '若い',
#    '男',
#    '相手',
#    'さ',
#    'れ',
#    '草食',
#    '男子',
#    '名付け',
#    '恨み',
#    'はらし',
#    'いる',
#    '言わ',
#    'れ',
#    '言い',
#    '気持ち',
#    'わかる',
#    'の',
#    '笑',
#    'いい',
#    '意味',
#    '名付け',
#    'いる',
#    '誤解',
#    'ん']},
#  {'score': 0.24266352311040612, 'token_seq': ['時', '衝撃', '今', '忘れ']},
#  {'score': 0.2424675866434207,
#   'token_seq': ['通知',
#    'メール',
#    '多',
#    'すぎる',
#    '通知',
#    'メール',
#    '停止',
#    'でき',
#    'やめ',
#    'いい',
#    'よかっ']},
#  {'score': 0.24222618261770226,
#   'token_seq': ['CM',
#    'お笑い',
#    '好き',
#    '人',
#    '作れ',
#    '知ら',
#    '作っ',
#    'い',
#    '怖い',
#    '話し',
#    '岡村',
#    'トミーズ',
#    '話',
#    '通っ',
#    'い',
#    'の',
#    '語っ']},
#  {'score': 0.2421958117179023,
#   'token_seq': ['さんま',
#    '昔',
#    '反日',
#    '日本',
#    '代表',
#    '欧州',
#    'チーム',
#    '勝つ',
#    '明らか',
#    '機嫌',
#    'なる',
#    '今日',
#    'さんま',
#    '正しい',
#    '俺',
#    'フランス',
#    '応援',
#    'し',
#    'て',
#    'それ',
#    'なでしこ',
#    '酷い',
#    'サッカー',
#    '国',
#    '決勝',
#    'あがら',
#    'ほしい',
#    '人',
#    'それぞれ',
#    '意見',
#    '違う',
#    'の',
#    '当たり前',
#    'さんま',
#    'さん',
#    '気持ち',
#    'マジ',
#    'わかる',
#    'さんま',
#    '率直',
#    '発言',
#    '擁護',
#    'する',
#    '声',
#    'み',
#    'られ']},
#  {'score': 0.24193075453671067,
#   'token_seq': ['テレビ',
#    '出',
#    '多く',
#    '人',
#    '自分',
#    '意見',
#    '言える',
#    '何',
#    '⁉',
#    '態度',
#    '⁉']},
#  {'score': 0.2411505938787682,
#   'token_seq': ['実名',
#    '出し',
#    'あと',
#    '木村',
#    '萩原',
#    '撮影',
#    '時',
#    '監督',
#    '話',
#    'ある',
#    'ん',
#    'いい',
#    '始まっ',
#    'の',
#    'イラ',
#    'つい',
#    '何',
#    '現場',
#    '止め',
#    'ん',
#    'コノ',
#    '野郎',
#    '横',
#    'マージャン',
#    '雑誌',
#    '読ん',
#    'て',
#    'バカ',
#    '?',
#    '思っ',
#    '語気',
#    '強め',
#    'まくしたて']},
#  {'score': 0.24105792453348393,
#   'token_seq': ['韓',
#    '流',
#    '批判',
#    'し',
#    '杉本',
#    'さん',
#    '芸能',
#    '界',
#    '消さ',
#    'れ',
#    '心配',
#    'し',
#    'しまう',
#    '別',
#    '悪口',
#    '言っ',
#    'てる',
#    'わけ',
#    'ただ',
#    '個人',
#    '的',
#    '感想',
#    'ん',
#    'マスコミ',
#    '的',
#    '凍りつく',
#    '言動',
#    '大丈夫',
#    '?」「',
#    'ラジオ',
#    '良かっ',
#    'しれ',
#    'テレビ',
#    '発言',
#    '無理',
#    '韓',
#    '流',
#    '批判',
#    'タブー',
#    'おかし',
#    '杉本',
#    '彩',
#    '今後',
#    '心配',
#    'する',
#    '声',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.24105638243523536,
#   'token_seq': ['記事',
#    '受け',
#    'ツイッター',
#    'ただ',
#    '変',
#    '人',
#    'おもっ',
#    'イメージ',
#    '変わっ',
#    '文章',
#    'うまい',
#    '会見',
#    '違い',
#    'まっとう',
#    '事',
#    '言っ',
#    'い',
#    'ギャップ',
#    'いい',
#    '田中',
#    '氏',
#    '賛辞',
#    '声',
#    '多く',
#    '寄せ',
#    'られ']},
#  {'score': 0.2406488122791082,
#   'token_seq': ['ネット',
#    'ユーザー',
#    '杉本',
#    '彩',
#    'かっこよ',
#    'すぎ',
#    '芸能人',
#    '一部',
#    '除い',
#    '考え',
#    '腹',
#    '溜め込ん',
#    'でる',
#    '人',
#    'いる',
#    'の',
#    'うち',
#    '職場',
#    '韓',
#    '流',
#    'ファン',
#    '多く',
#    '好き',
#    '好き',
#    '良い',
#    'ん',
#    '正直',
#    '会話',
#    'つらい',
#    '確か',
#    '韓',
#    '流',
#    '無理',
#    'し',
#    '褒め',
#    'すぎ',
#    '気',
#    'する',
#    '静か',
#    'ブーム',
#    '言っ',
#    'とけ',
#    '良い',
#    'の',
#    '杉本',
#    '発言',
#    '賛同',
#    'する',
#    '声',
#    '相次い']},
#  {'score': 0.2406014381240894,
#   'token_seq': ['発言',
#    'ネット',
#    '正論',
#    '正論',
#    'すぎる',
#    '子供',
#    '申し訳',
#    '言い',
#    '福島',
#    '離れ',
#    '親',
#    'ども',
#    '糞',
#    'すぎる',
#    'たま',
#    'まとも',
#    'こと',
#    '言う',
#    'の',
#    '肯定',
#    '的',
#    '意見',
#    '多く',
#    '見',
#    'られる',
#    '何',
#    '考え',
#    'て',
#    'の',
#    'タラコ',
#    '自身',
#    'これ',
#    '東北',
#    'こいつ',
#    '訴え',
#    'ほう',
#    'いい',
#    '発言',
#    '許し',
#    '置け',
#    '否定',
#    '的',
#    '声',
#    '出',
#    'おり',
#    '意見',
#    '激しく',
#    'ぶつかり',
#    '合っ',
#    'いる']},
#  {'score': 0.24041081955461688,
#   'token_seq': ['驚き',
#    '校了',
#    'そこ',
#    '権力',
#    'ある',
#    'もの',
#    '出し',
#    'いか',
#    '言っ',
#    '人間',
#    '顔',
#    '名前',
#    '私',
#    '一生',
#    '知る',
#    'こと',
#    'でき',
#    'の',
#    '北朝鮮',
#    'かよ',
#    '思い',
#    '大げさ']},
#  {'score': 0.24034451429783818,
#   'token_seq': ['わかん',
#    '感覚',
#    'みんな',
#    '番組',
#    '作っ',
#    'てる',
#    '視聴',
#    '者',
#    '離れ',
#    'いっ',
#    'てる',
#    'ん']},
#  {'score': 0.24029960265703498,
#   'token_seq': ['篠田',
#    '書き込み',
#    'イジメ',
#    '思え',
#    'しまう',
#    '読解',
#    '力',
#    'すごい',
#    '信頼',
#    '関係',
#    'ある',
#    '身内',
#    '言う',
#    '場合',
#    'いじめ',
#    '救い',
#    '外部',
#    'いじめ',
#    'これ',
#    'イジリ',
#    '仲良かっ',
#    '普通',
#    'いじめ',
#    '隠れ',
#    'する',
#    'もん',
#    'する',
#    'わけ',
#    'ない',
#    'いじめ',
#    '説',
#    '反論',
#    '多く',
#    '寄せ',
#    'られ']},
#  {'score': 0.24000621131638736,
#   'token_seq': ['東京',
#    '京都',
#    '遠距離',
#    '恋愛',
#    '旦那',
#    'さん',
#    '東京',
#    '来る',
#    '時',
#    '張り切っ',
#    'ご飯',
#    '作っ',
#    'い']},
#  {'score': 0.23967999359766207,
#   'token_seq': ['瞬間',
#    '山崎',
#    'ヒートアップ',
#    'し',
#    'いく',
#    '芸人',
#    '年功序列',
#    '関係',
#    'ない',
#    '面白',
#    'さ',
#    '俺',
#    'やっ',
#    'たる',
#    'ここ',
#    '笑い声',
#    'スタッフ',
#    '側',
#    'どこ',
#    '沸く',
#    'それ',
#    '聞い',
#    '山崎',
#    '邦正',
#    '激怒',
#    'し']},
#  {'score': 0.23927679953551972, 'token_seq': ['確実', '殺し']},
#  {'score': 0.2391264320090248,
#   'token_seq': ['AKB',
#    '48',
#    '卒業',
#    'する',
#    '前田',
#    '女優',
#    'やり',
#    'の',
#    'あっ',
#    'わし',
#    '甘え',
#    'い',
#    '中略',
#    '真剣',
#    '前田',
#    '敦子',
#    '絶賛',
#    'す',
#    '後悔',
#    '念',
#    '綴っ']},
#  {'score': 0.2388527754889234,
#   'token_seq': ['坂',
#    '菜',
#    '緒',
#    'やら',
#    'やら',
#    'ぱ',
#    'ぱ',
#    'パン',
#    'スト',
#    'くれ',
#    'ぁ',
#    '☆*:.。.',
#    'o',
#    '(≧▽≦)',
#    'o',
#    '.。.:*☆！！！」',
#    '返答',
#    '菜',
#    '緒',
#    'パン',
#    'スト',
#    '古',
#    '坂',
#    '猫',
#    '交換',
#    'しよ',
#    '提案',
#    '冗談',
#    'っぽく',
#    'し',
#    'ところ',
#    '以来',
#    '菜',
#    '緒',
#    '無視',
#    'さ',
#    'れ',
#    'いる',
#    'の',
#    'いう']},
#  {'score': 0.2386248692085499, 'token_seq': ['当たり前', '対応']},
#  {'score': 0.2384745953494555,
#   'token_seq': ['岡村',
#    '現在',
#    '41',
#    '歳',
#    '事実',
#    '踏まえ',
#    '41',
#    '歳',
#    '歳',
#    '相応',
#    '禿げ',
#    '禿げ',
#    'あんま',
#    '気',
#    'し',
#    'いい',
#    '歳',
#    '?」',
#    '岡村',
#    '擁護',
#    'する',
#    '声',
#    '上がっ',
#    'いる']},
#  {'score': 0.23845206432234337,
#   'token_seq': ['有吉',
#    '援軍',
#    '受け',
#    '升野',
#    'たま',
#    'いる',
#    'ペーペー',
#    'バーター',
#    'クセ',
#    'わたし',
#    'バーター',
#    'みたい',
#    '顔',
#    'し',
#    'そこ',
#    '出る',
#    'の',
#    'どれ',
#    '難しい',
#    'の',
#    '知ら',
#    'バーター',
#    '当たり前',
#    'よう',
#    '出',
#    'コメント',
#    'せ',
#    '映る',
#    '映っ',
#    'タクシー',
#    '券',
#    '受け取り',
#    'ブログ',
#    '今日',
#    '番組',
#    '楽しかっ',
#    '言う',
#    '奴',
#    '楽しかっ',
#    'おまえ',
#    '誰',
#    '楽しま',
#    'せ',
#    'て',
#    '怒り',
#    'ヒートアップ',
#    'さ',
#    'せ']},
#  {'score': 0.23827948707780514,
#   'token_seq': ['私',
#    '愛する',
#    '愛さ',
#    'れる',
#    '信じる',
#    'こと',
#    'わから',
#    '私',
#    'こと',
#    '嫌い',
#    'なる',
#    'ん',
#    '気持ち',
#    '根底',
#    'ある',
#    '略',
#    '私',
#    '嫌',
#    '部分',
#    '彼',
#    '嫌',
#    'ストレス',
#    '感じる',
#    '大切',
#    '部分',
#    '合わ',
#    '事',
#    'の',
#    '略',
#    '彼',
#    'こと',
#    '好き',
#    '一緒',
#    'い',
#    '不安',
#    '不安',
#    'だらけ',
#    '私',
#    '恋愛',
#    '障害',
#    '抱え',
#    'いる',
#    'よう']},
#  {'score': 0.23827942009447906,
#   'token_seq': ['俺',
#    '絶対',
#    '食い',
#    'ブログ',
#    '書か',
#    '店員',
#    '親父',
#    '聞こえる',
#    'よう',
#    '言わ',
#    '叩か',
#    'れる',
#    'の',
#    '承知',
#    '感度',
#    '下がる',
#    'よう',
#    'こと',
#    '書い',
#    'てる',
#    'ん',
#    '信念',
#    '基づい',
#    '発言',
#    'ん',
#    '俺',
#    '支持',
#    'する',
#    '矢野',
#    '発言',
#    '是非',
#    '問う',
#    '激しい',
#    '議論',
#    '繰り広げ',
#    'られ',
#    'いる',
#    '一方',
#    '矢野',
#    '沙織',
#    '誰',
#    '誰',
#    'わから',
#    '知ら',
#    'コメント',
#    '相次い',
#    'いる']},
#  {'score': 0.2378519481194482,
#   'token_seq': ['はじまり',
#    '離婚',
#    'し',
#    '3',
#    'ヶ月',
#    'し',
#    '時',
#    '娘',
#    '誕生',
#    '日',
#    'あっ',
#    'ん',
#    'プレゼント',
#    '三輪車',
#    'いい',
#    'いう',
#    '買い',
#    '行こ',
#    '思っ',
#    'ん',
#    '色',
#    'キャラクター',
#    '買っ',
#    '娘',
#    '気に入っ',
#    'くれ',
#    'かわいそう',
#    '誘っ',
#    'み',
#    'ん',
#    '二',
#    '人',
#    '来る',
#    '三',
#    '人',
#    '買い',
#    '行っ',
#    'ん',
#    '語っ',
#    '井戸田',
#    'それ',
#    '機',
#    '頻繁',
#    '会う',
#    'よう',
#    'なっ',
#    'ん',
#    'あれ',
#    'これ',
#    'こと',
#    '思っ',
#    '自分',
#    '中',
#    '解釈',
#    'し',
#    'これ',
#    'いける',
#    '思っ',
#    'ん',
#    '頻繁',
#    '会っ',
#    'てる',
#    '一',
#    '回',
#    'やり直さ',
#    '言っ',
#    'み',
#    'ん',
#    'くい',
#    '気味',
#    '奥さん',
#    'ムリムリムリムリムリムリムリーーー',
#    '温度',
#    '差',
#    'あん',
#    '思っ',
#    'エピソード',
#    '明かす']},
#  {'score': 0.23736316161729265,
#   'token_seq': ['ストップ',
#    'かけ',
#    '校了',
#    '者',
#    'たち',
#    'もん',
#    '編集',
#    '部',
#    '俺',
#    'たち',
#    '良識',
#    '派',
#    'いい',
#    'なり',
#    'バーカ',
#    '得意',
#    'なっ',
#    '本気',
#    '恐ろしい']},
#  {'score': 0.23728196413559757,
#   'token_seq': ['ネット',
#    'ユーザー',
#    '反応',
#    'マツコ',
#    '言っ',
#    'くれ',
#    'ありがたい',
#    '思う',
#    'とき',
#    'マツコ',
#    'かっこよかっ',
#    'ここ',
#    'テレビ',
#    '言い',
#    'こと',
#    '言う',
#    'の',
#    '凄い',
#    'マツコ',
#    'かわいい',
#    'マツコ',
#    'マツコ',
#    'デラックス',
#    '意見',
#    '賛同',
#    'する',
#    'もの',
#    '多い',
#    '一部',
#    'ユーザー',
#    'フジ',
#    'ガス',
#    '抜き',
#    'マツコ',
#    '干さ',
#    'れ',
#    '心配',
#    '書き込み',
#    'あっ']},
#  {'score': 0.2372617426613268,
#   'token_seq': ['ネット',
#    '掲示板',
#    '江原',
#    '啓之',
#    '発言',
#    'お前',
#    '言う',
#    '騙さ',
#    'れる',
#    '奴',
#    '悪い',
#    'こと',
#    '言わ',
#    '仕事',
#    'なくなる',
#    'もん',
#    '非難',
#    '声',
#    'あがる',
#    '一方',
#    '他',
#    '奴',
#    'みんな',
#    '洗脳',
#    '洗脳',
#    '中島',
#    '被害',
#    '者',
#    'みたい',
#    '言っ',
#    'てる',
#    '発言',
#    '新鮮',
#    'これ',
#    '正論',
#    '中島',
#    'かわいそう',
#    '報道',
#    '無理',
#    'ある',
#    '確か',
#    'いい',
#    '大人',
#    '家賃',
#    '払っ',
#    'てれ',
#    '社会',
#    '的',
#    '問題',
#    'ない',
#    '江原',
#    '擁護',
#    '家賃',
#    '滞納',
#    'し',
#    'てる',
#    '大人',
#    '悪い',
#    'オセロ',
#    '中島',
#    '被害',
#    '者',
#    'ない',
#    'する',
#    '江原',
#    '賛同',
#    'する',
#    '声',
#    '多く',
#    '見',
#    'られ']},
#  {'score': 0.23701465176045527,
#   'token_seq': ['自分', '手柄', 'よう', '報じる', '英', 'メディア', '気持ち', '悪い']},
#  {'score': 0.23700653266059188,
#   'token_seq': ['ナイ', 'ナイ', '岡村', '頭髪', 'ヤバ', 'すぎる', '話題']},
#  {'score': 0.23684249256841536,
#   'token_seq': ['２',
#    'ちゃん',
#    'ねる',
#    '管理',
#    '人',
#    'ひろ',
#    'ゆき',
#    '氏',
#    '嘘',
#    '嘘',
#    '見抜け',
#    '難しい',
#    '語っ',
#    'ナインティナイン',
#    '2',
#    '人',
#    '番組',
#    'スタッフ',
#    '嘘',
#    '嘘',
#    '見抜け',
#    'よう']},
#  {'score': 0.2363262117994053,
#   'token_seq': ['報道',
#    '受け',
#    'ネット',
#    '掲示板',
#    'イケメン',
#    '思う',
#    '放尿',
#    '題名',
#    'ない',
#    '飛',
#    'びすぎててついていけん',
#    'タイトル',
#    'あまり',
#    'インパクト',
#    '驚き',
#    '戸惑い',
#    '声',
#    '相次い']},
#  {'score': 0.236053783341382, 'token_seq': ['鈴木', '京香']},
#  {'score': 0.23603256928011593,
#   'token_seq': ['たま', '視聴', '者', 'オススメ', 'ー', 'ＰＯＰ', 'の', 'やっ', 'ほしい']},
#  {'score': 0.2355793664135553,
#   'token_seq': ['友達',
#    '少ない',
#    '回答',
#    'し',
#    '桑原',
#    '社交',
#    '的',
#    'ん',
#    '友達',
#    '少ない',
#    '暴露',
#    '続け',
#    '秦',
#    '至っ',
#    'パパ',
#    '嫌い',
#    '曲',
#    'ある',
#    'ん',
#    'それ',
#    '不良',
#    'っぽい',
#    '感じ',
#    'みんな',
#    '髪',
#    '盛っ',
#    'いる',
#    'の',
#    '怜奈',
#    '松井',
#    '髪の毛',
#    '少なく',
#    '一',
#    '人',
#    'カツラ',
#    'ん',
#    '仰天',
#    'エピソード',
#    '話し',
#    '秘密',
#    '暴露',
#    'し',
#    '秦',
#    '松井',
#    'ヒドイ',
#    '笑い',
#    'どこ',
#    '怒っ',
#    'いる',
#    'よう']},
#  {'score': 0.23547436963025054,
#   'token_seq': ['中',
#    '日本',
#    'タレント',
#    '活動',
#    'し',
#    'いる',
#    'オマエ',
#    '言う',
#    '!!」「',
#    'フィフィ',
#    'なん',
#    '外国',
#    '人',
#    '厳しい',
#    'ん',
#    '?」「',
#    'ツイッター',
#    '他人',
#    '貶める',
#    'こと',
#    '書か',
#    'ダメ',
#    'わけ',
#    '?」',
#    'フィフィ',
#    '唐突',
#    '猫',
#    'ひろし',
#    '批判',
#    '疑問',
#    '呈する',
#    '声',
#    'あっ',
#    '全体',
#    '的',
#    'フィフィ',
#    '意見',
#    '支持',
#    'する',
#    '意見',
#    '多かっ']},
#  {'score': 0.23521919756684562,
#   'token_seq': ['これ',
#    'ネット',
#    '掲示板',
#    'ぎやはぎを',
#    '否定',
#    'できる',
#    '立場',
#    '!?',
#    'オマエ',
#    '頑張っ',
#    'てる',
#    '人',
#    'たち',
#    '毎回',
#    '否定',
#    'し',
#    'き',
#    'これ',
#    '騒ぎ',
#    '大きく',
#    'なれ',
#    '高橋',
#    'みなみ',
#    '迷惑',
#    'する',
#    '周り',
#    '見え',
#    'なっ',
#    'ちゃっ',
#    'てる',
#    '最後',
#    '小木',
#    '日和',
#    'オチ',
#    '最大',
#    'ミソ',
#    'それ',
#    '無視',
#    'し',
#    'ブチ',
#    '切れる',
#    '恥ずかしい',
#    '小林',
#    '氏',
#    '非難',
#    'する',
#    '声',
#    '溢れ',
#    '返っ',
#    'い']},
#  {'score': 0.2351819038663828,
#   'token_seq': ['安易', '即座', '"', 'インスタント', 'セックス', '"', 'あなた', '周り', 'あり']},
#  {'score': 0.23408591121682074,
#   'token_seq': ['スギ',
#    'ちゃん',
#    '知る',
#    '芸人',
#    '仲間',
#    'チェリー',
#    'ボーイ',
#    '彼',
#    'エピソード',
#    '紹介',
#    'さ',
#    'れる',
#    'ダウンタウン',
#    'さん',
#    '絡み',
#    '方',
#    '教え',
#    '電話',
#    'かかっ',
#    'き',
#    'チェリー',
#    'ボーイ',
#    'こと',
#    'ある',
#    'ごと',
#    '俺',
#    '浜田',
#    'さん',
#    'ハマっ',
#    'てる',
#    '言っ',
#    'くる',
#    'スギ',
#    'ちゃん',
#    '尊敬',
#    'する',
#    'ダウンタウン',
#    'エピソード',
#    '暴露',
#    'さ',
#    'れる',
#    '都度',
#    '絶対',
#    '言っ',
#    'て',
#    '松本',
#    'さん',
#    '目',
#    '見',
#    '下さい',
#    '絶対',
#    '言っ',
#    'て',
#    '釈明',
#    'する',
#    'スギ',
#    'ちゃん']},
#  {'score': 0.2336710992953893,
#   'token_seq': ['日',
#    '玉',
#    '袋',
#    '筋',
#    '太郎',
#    '指原',
#    '愛称',
#    '一つ',
#    'しこ',
#    'もじっ',
#    'せこ',
#    '貞操',
#    '観念',
#    'ない',
#    '女性',
#    '指す',
#    '隠語',
#    '発言',
#    '番組',
#    '指原',
#    'スキャンダル',
#    '話題',
#    'なる',
#    '記事',
#    '読む',
#    'ファン',
#    '食っ',
#    'てる',
#    'せこ',
#    'しこ',
#    '言い',
#    '間違い',
#    'し',
#    '昭和',
#    'アイドル',
#    'みんな',
#    'マネージャー',
#    '寝る',
#    '決まっ',
#    'て',
#    '西武',
#    '涌井',
#    '悪く',
#    'ん',
#    'それ',
#    '一緒',
#    '発言',
#    'し']},
#  {'score': 0.2335153872145077,
#   'token_seq': ['普通', '親', '子供', '大人', 'なっ', '通用', 'する', '名前', 'つける']},
#  {'score': 0.2329703468491799,
#   'token_seq': ['ナイ', 'ナイ', '岡村', 'テレビ', '見', '見る', '発言', '真相', '語る']},
#  {'score': 0.23290531432722542,
#   'token_seq': ['読売新聞',
#    '報道',
#    'ネット',
#    '上',
#    'ほんと',
#    '言っ',
#    'てる',
#    'ネタ',
#    '思っ',
#    'マジ',
#    '反応',
#    'する',
#    '人',
#    '居',
#    'の',
#    '為']},
#  {'score': 0.23265004183398003, 'token_seq': ['日銭', '取っ', 'てる', 'こと', '不思議']},
#  {'score': 0.23228109727565566,
#   'token_seq': ['応援',
#    'し',
#    '下さる',
#    '方',
#    '一',
#    '人',
#    'いる',
#    '私',
#    '自分',
#    '応援',
#    'し',
#    'い',
#    'アイドル',
#    '辞め',
#    '活動',
#    '停止',
#    'し',
#    'ちゃっ',
#    'ん',
#    '人',
#    'すごい',
#    '寂しい',
#    '思い',
#    'し',
#    'ん',
#    '考え',
#    '一',
#    '人',
#    '応援',
#    'し',
#    '下さる',
#    '方',
#    'いる',
#    '誰',
#    '何',
#    '言わ',
#    'れ',
#    'いる',
#    'ふう',
#    '話し',
#    '秋元',
#    '先生',
#    '何',
#    'なし',
#    'ここ',
#    'いる',
#    'の',
#    '変',
#    'お前',
#    '一',
#    'やり直し',
#    'HKT',
#    'ラジオ',
#    '生放送']},
#  {'score': 0.2322783508925432,
#   'token_seq': ['やっ',
#    'いつか',
#    '仁',
#    'DNA',
#    '混ざり',
#    '合う',
#    'それ',
#    'ファン',
#    '仁',
#    'Eternal',
#    'フレーズ',
#    '意味',
#    '何',
#    '度',
#    '読ん',
#    '分から',
#    '頭',
#    '大丈夫',
#    '?」',
#    '批判',
#    '通り越し',
#    'ユーザー',
#    '精神',
#    '状態',
#    '心配',
#    'する',
#    '意見',
#    '多く',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.23213878137945332,
#   'token_seq': ['応援', 'し', '頂き', '支え', '下さっ', 'いる', '全て', '皆様']},
#  {'score': 0.231978232612277,
#   'token_seq': ['番組',
#    '放送',
#    '中',
#    'ネット',
#    '掲示板',
#    '化けの皮',
#    'はがさ',
#    'れる',
#    'ww',
#    '必死',
#    '本当',
#    '本当',
#    '言っ',
#    'いる',
#    '矢口',
#    '真里',
#    '言い訳',
#    '苦しい',
#    '恥',
#    '上塗り',
#    'し',
#    'てる',
#    '矢口',
#    '弁明',
#    '批判',
#    '声',
#    '上がり',
#    'モーニング',
#    '娘',
#    '詳しい',
#    'ネット',
#    'ユーザー',
#    'テレビ',
#    'ネタ',
#    '触れる',
#    '触れ',
#    'いけ',
#    'タブー',
#    '意見',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.23196577064632476,
#   'token_seq': ['仲',
#    '睦まじい',
#    '様子',
#    'ネット',
#    '掲示板',
#    '上',
#    '子',
#    '旦那',
#    'ラブラブ',
#    'これ',
#    '言う',
#    '見せ付け',
#    'くる',
#    'の']},
# ...
#    '言っ',
#    'ちゃう',
#    'ん',
#    '痛快',
#    '言う',
#    '奴',
#    '神経',
#    '疑う',
#    '大量',
#    '殺人',
#    '凶悪',
#    '犯',
#    'しれ',
#    '木嶋',
#    '被告',
#    '共感',
#    '大丈夫',
#    'の',
#    '日本',
#    '木嶋',
#    '被告',
#    'モテ',
#    '術',
#    '学ぼ',
#    'し',
#    'いる',
#    'よう',
#    '女性',
#    'たち',
#    '批判',
#    '声',
#    '相次ぎ',
#    '木嶋',
#    '被告',
#    '男',
#    '捕まえ',
#    'の',
#    'ターゲット',
#    '選び',
#    '上手かっ',
#    'モテ',
#    'わけ',
#    '意見',
#    '見',
#    'られ']},
#  {'score': 0.1566607389136187,
#   'token_seq': ['他',
#    '韓',
#    '流',
#    'ゴリ押し',
#    'うるさい',
#    'ネット',
#    '住民',
#    '今度',
#    '出版',
#    '社',
#    'デモ',
#    '行く',
#    'つもり',
#    '?」',
#    '行き過ぎ',
#    '韓国',
#    '批判',
#    '諌める',
#    '声',
#    '表紙',
#    '韓国',
#    '字',
#    'ない',
#    '中身',
#    '韓国',
#    '推し',
#    '表紙',
#    '見',
#    '買っ',
#    '読者',
#    'し',
#    '読者',
#    '心情',
#    '案ずる',
#    '声',
#    '様々',
#    '意見',
#    '書き込ま',
#    'れ']},
#  {'score': 0.15660875707112826,
#   'token_seq': ['スタジオ',
#    '平壌',
#    '非常',
#    '豊か',
#    '地方',
#    '格差',
#    'ある',
#    '高',
#    '英',
#    '起',
#    'デイリー',
#    'NK',
#    '今後',
#    '何',
#    '問題',
#    'あれ',
#    'そこ',
#    '出',
#    'くれ',
#    '話',
#    'ある',
#    'ん',
#    '岩田',
#    '宗一',
#    'TBS',
#    '報道局',
#    '解説',
#    '委員',
#    '金',
#    '正',
#    '恩',
#    '氏',
#    '藤本',
#    '氏',
#    'どれ',
#    '大切',
#    '人',
#    '分かる',
#    '金',
#    '正',
#    '恩',
#    '氏',
#    '大盤振る舞い',
#    '鈴木',
#    '琢磨',
#    '毎日新聞',
#    '編集',
#    '委員',
#    'コメント',
#    '寄せ',
#    'られ']},
#  {'score': 0.1565056299137771,
#   'token_seq': ['妻',
#    '千秋',
#    '間',
#    'でき',
#    '子ども',
#    '会う',
#    '際',
#    '子ども',
#    '千秋',
#    '家',
#    '迎え',
#    '行っ',
#    'うち',
#    '泊まる',
#    '時',
#    '千秋',
#    'トイレ',
#    '貸し',
#    'くれ',
#    '切り出し',
#    '遠藤',
#    '千秋',
#    '家',
#    '玄関',
#    'バタ',
#    'ン',
#    '閉め',
#    '瞬間',
#    '家',
#    '中',
#    '千秋',
#    'プシュー',
#    'プシュー',
#    '臭',
#    '剤',
#    'まい',
#    'いる',
#    '明かす',
#    '過酷',
#    '実情',
#    'スタジオ',
#    '驚き',
#    '声',
#    'あがる',
#    'アメトーーク',
#    '!」',
#    '思え',
#    '悲壮',
#    '感',
#    'たっぷり',
#    '内容',
#    'なっ',
#    '今回',
#    '安達',
#    '祐実',
#    '離婚',
#    'し',
#    '井戸田',
#    '番組',
#    '内',
#    '復縁',
#    '活動',
#    '断念',
#    '宣言',
#    'し']},
#  {'score': 0.15647805804215018,
#   'token_seq': ['年俸',
#    '高',
#    'すぎる',
#    '今',
#    'サッカー',
#    '選手',
#    '自分',
#    '見つめ',
#    'なおす',
#    'いい',
#    '機会',
#    'サッカー',
#    '選手',
#    'たち',
#    '金',
#    '女',
#    '名声',
#    '追いかけ',
#    'いる',
#    '韓国',
#    '方',
#    '強かっ',
#    'イギリス',
#    '代表',
#    '批判',
#    '多く',
#    '寄せ',
#    'られ']},
#  {'score': 0.15637843983700728,
#   'token_seq': ['視聴',
#    '者',
#    'なめ',
#    'いる',
#    '問題',
#    'なる',
#    'テレビ',
#    '業界',
#    'やら',
#    'せ',
#    '問題',
#    '大御所',
#    'けし',
#    '違う',
#    '信頼',
#    '寄せ',
#    'いる',
#    'ユーザー',
#    '多かっ',
#    'よう',
#    'たけし',
#    'やら',
#    'せ',
#    '一員',
#    '見損なっ',
#    '落胆',
#    'する',
#    '声',
#    '見',
#    'られ']},
#  {'score': 0.1563640076426591,
#   'token_seq': ['ブログ',
#    '皆さん',
#    '伝える',
#    'する',
#    '事',
#    '遅く',
#    'なり',
#    '一文',
#    '始まり',
#    '母親',
#    '事件',
#    '謝罪',
#    '分かる',
#    '具体',
#    '的',
#    'フレーズ',
#    'ない',
#    '度',
#    '心配',
#    '掛け',
#    'し',
#    'し',
#    'しまっ',
#    '事',
#    '大変',
#    '騒がせ',
#    'させ',
#    'しまっ',
#    '事',
#    '申し訳',
#    'あり',
#    '綴り',
#    '今後',
#    'AKB',
#    '48',
#    '活動',
#    '続け',
#    'いく',
#    '意思',
#    '伝え',
#    'い']},
#  {'score': 0.15629520972681665,
#   'token_seq': ['ネーム',
#    'ネット',
#    'スラング',
#    'DQN',
#    'ネーム',
#    '呼ば',
#    'れる',
#    '奇妙',
#    '奇天烈',
#    '名前',
#    'こと',
#    '日',
#    'コーナー',
#    '笑',
#    '門',
#    'えも',
#    '捲',
#    '理',
#    '(',
#    'まくり',
#    ')」「',
#    '波',
#    '波',
#    '波',
#    'さん',
#    '名前',
#    '紹介',
#    'さ',
#    'れ']},
#  {'score': 0.15619974680881218,
#   'token_seq': ['今回',
#    '報道',
#    'よる',
#    '体',
#    '鈍い',
#    '痛み',
#    'ある',
#    '症状',
#    '加え',
#    '寝',
#    'いる',
#    '時',
#    '周囲',
#    'もの',
#    '投げる',
#    '前代未聞',
#    '症状',
#    '訴え',
#    'い',
#    'こと',
#    '分かり',
#    'ネット',
#    '上',
#    '原発',
#    '風力',
#    '人',
#    '居',
#    'とこ',
#    '建てる',
#    '批判',
#    'コメント',
#    '相次い']},
#  {'score': 0.15617777516623466,
#   'token_seq': ['19',
#    '日',
#    'なっ',
#    '日刊',
#    'サイゾー',
#    '芸人',
#    '河本',
#    '準一',
#    '報じ',
#    '騒ぎ',
#    '拡大',
#    '記事',
#    '真偽',
#    '不確か',
#    '状態',
#    '掲示板',
#    '家族',
#    '養える',
#    '能力',
#    'ある',
#    'やつ',
#    '生活',
#    '保護',
#    '許す',
#    '金',
#    'ある',
#    '自分',
#    '親',
#    '養え',
#    '税金',
#    '使っ',
#    'クズ',
#    '怒り',
#    '声',
#    '殺到',
#    'し']},
#  {'score': 0.15610539662607245,
#   'token_seq': ['2',
#    '人',
#    '灘',
#    '高',
#    '時代',
#    '同級生',
#    'お互い',
#    'トップ',
#    '成績',
#    '維持',
#    'し',
#    'おり',
#    '生徒',
#    '間',
#    '学年',
#    '双璧',
#    '知ら',
#    'れ',
#    'い',
#    '当時',
#    '知る',
#    '同級生',
#    '太田',
#    'さん',
#    '嫌み',
#    'ない',
#    'いたずら',
#    '心',
#    'あっ',
#    '人望',
#    '厚い',
#    '身長',
#    'イケメン',
#    'テスト',
#    '時',
#    'お願い',
#    'すれ',
#    '解き',
#    '終え',
#    'トイレ',
#    '答え',
#    '教え',
#    'くれ',
#    '彼',
#    '素顔',
#    '明かし',
#    'いる']},
#  {'score': 0.15606821092041967,
#   'token_seq': ['ニュース',
#    '日本',
#    'ネット',
#    '掲示板',
#    '上',
#    '話題',
#    'なり',
#    '元',
#    '写真',
#    '左右',
#    '対称',
#    'なる',
#    'よう',
#    '修整',
#    'し',
#    'てる',
#    'ん',
#    '本気',
#    'かわいい',
#    '思っ',
#    'いる',
#    'ん',
#    '日',
#    '韓',
#    '価値',
#    '観',
#    '差',
#    '大きい',
#    '批判',
#    '的',
#    '意見',
#    '日本',
#    '韓国',
#    '整形',
#    '大国',
#    'イメージ',
#    'ある',
#    'ため',
#    '整形',
#    '技術',
#    '賞賛',
#    'キム',
#    'ヨナ',
#    '賛美',
#    '揶揄',
#    'する',
#    'よう',
#    '書き込み',
#    '見',
#    'られ']},
#  {'score': 0.15604882014239493,
#   'token_seq': ['一方',
#    'マリコ',
#    '様',
#    'ー',
#    '実力',
#    '者',
#    '発言',
#    '重み',
#    'ある',
#    '潰す',
#    '気持ち',
#    'でき',
#    'ww',
#    'プロレス',
#    'みたい',
#    '心意気',
#    '評価',
#    'し',
#    '声',
#    '寄せ',
#    'られ',
#    '賛否',
#    '両論',
#    'どちら',
#    '偏る',
#    'こと',
#    'なく',
#    '5',
#    '位',
#    '人気',
#    '高',
#    'さ',
#    'うかがわ',
#    'せ']},
#  {'score': 0.15599652798445593,
#   'token_seq': ['韓国',
#    'ネット',
#    '掲示板',
#    '日本',
#    '批判',
#    'する',
#    '前',
#    '国民',
#    '売る',
#    '連中',
#    '処罰',
#    'す',
#    '君',
#    'ら',
#    'せい',
#    '日本人',
#    '慰安',
#    '婦',
#    '被害',
#    '者',
#    '娼婦',
#    'みなし',
#    'いる',
#    '我々',
#    '君',
#    'ら',
#    '保護',
#    'する',
#    '責任',
#    'ない',
#    'ブローカー',
#    '女性',
#    '側',
#    '批判',
#    'する',
#    '声',
#    '目立っ']},
#  {'score': 0.1559839514061386,
#   'token_seq': ['指原',
#    '起用',
#    '受け',
#    'ネット',
#    '掲示板',
#    'これ',
#    '本人',
#    '可哀想',
#    '本物',
#    'モデル',
#    '比べる',
#    '見劣り',
#    'する',
#    '決まっ',
#    'てる',
#    'ん',
#    '恥ずかしい',
#    '板野',
#    '引き続き',
#    '公開',
#    '処刑',
#    '指原',
#    '起用',
#    '疑問',
#    '声',
#    '上がっ',
#    'いる']},
#  {'score': 0.15591832198774208,
#   'token_seq': ['その他',
#    '指原',
#    '交際',
#    '暴露',
#    'し',
#    'さ',
#    'れる',
#    '男性',
#    '男',
#    '強い',
#    '口調',
#    '罵っ',
#    'さんま',
#    '男',
#    '風上',
#    '置けん',
#    'よう',
#    '奴',
#    'ショック',
#    '彼',
#    'カノ',
#    '暴露',
#    'さ',
#    'れる',
#    '語っ',
#    '一方',
#    '06',
#    '年',
#    '石原',
#    '真理',
#    '書い',
#    '暴露',
#    '本',
#    '自身',
#    '交際',
#    '暴露',
#    'さ',
#    'れ',
#    '過去',
#    '触れ',
#    '自虐',
#    '的',
#    '笑う']},
#  {'score': 0.15591541034170958,
#   'token_seq': ['今回',
#    'クローズアップ',
#    '現代',
#    'テーマ',
#    'なっ',
#    'の',
#    '羊水',
#    '卵子',
#    'ネット',
#    '掲示板',
#    '倖田',
#    '來未',
#    'ある',
#    '意味',
#    '正しかっ',
#    'の',
#    '?」「',
#    '言い方',
#    '違う',
#    '羊水',
#    '腐る',
#    'の',
#    '間違い',
#    'なかっ',
#    '高齢',
#    '出産',
#    '警告',
#    '意味',
#    'あど',
#    '倖田',
#    '擁護',
#    'する',
#    '声',
#    '相次い',
#    'の']},
#  {'score': 0.1559042743073034,
#   'token_seq': ['魂', '私', '子供', '子供', '孫', '受け継が', 'れ', 'いく']},
#  {'score': 0.1558891357007901,
#   'token_seq': ['放送',
#    '直後',
#    'ネット',
#    '掲示板',
#    '上',
#    'ありえ',
#    '名前',
#    'つけ',
#    'られ',
#    '子供',
#    '可哀想',
#    '動物',
#    'あつかい',
#    '名前',
#    '付け',
#    '親',
#    '批判',
#    '殺到',
#    '中',
#    '就活',
#    '時',
#    'ふざけ',
#    'てる',
#    '思わ',
#    'れる',
#    '赤ちゃん',
#    '将来',
#    '案じる',
#    '意見',
#    '上がっ',
#    'よう',
#    'ネーム',
#    '珍',
#    '名',
#    '増え',
#    '続ける',
#    '日本',
#    '将来',
#    '憂う',
#    '声',
#    '多く',
#    '肯定',
#    '的',
#    '意見',
#    'なかっ']},
#  {'score': 0.15576276444859566,
#   'token_seq': ['天海',
#    '信長',
#    '意外',
#    '違和感',
#    'なく',
#    'ワロタ',
#    'ww',
#    '髭',
#    'チョンマゲ',
#    '似合い',
#    'すぎ',
#    '!!」「',
#    'あり',
#    'え',
#    '設定',
#    '役者',
#    '演技',
#    '力',
#    'みる',
#    'もの',
#    '説得',
#    'さ',
#    'せ',
#    'いけ',
#    '実力',
#    '派',
#    '天海',
#    'できる',
#    'こと',
#    '宝塚',
#    'トップ',
#    'スター',
#    '引退',
#    '後',
#    '数々',
#    'ドラマ',
#    '男前',
#    'キャラ',
#    '演じ',
#    '天海',
#    '期待',
#    'する',
#    '声',
#    'み',
#    'られ']},
#  {'score': 0.1557392550915536,
#   'token_seq': ['中島',
#    '異常',
#    'コメント',
#    'し',
#    'い',
#    '相方',
#    '松嶋',
#    '一時期',
#    '霊',
#    '能',
#    '者',
#    '人',
#    'すごい',
#    '当たる',
#    '讃え',
#    'い',
#    'いう',
#    'その後',
#    '自分',
#    '離れ',
#    '同誌',
#    '報じ',
#    'いる']},
#  {'score': 0.1556799176698021,
#   'token_seq': ['記事',
#    'よる',
#    'テレビ局',
#    '伝え',
#    '映像',
#    '登場',
#    'し',
#    '高級',
#    'スポーツカー',
#    '愛好',
#    '家',
#    '30',
#    '代',
#    '夫婦',
#    'リーゼント',
#    '頭',
#    '鼠色',
#    '毛皮',
#    'ロング',
#    'コート',
#    '羽織っ',
#    'い',
#    'ヤンキー',
#    '上がり',
#    'っぽく',
#    '奥さん',
#    'ほう',
#    '金髪',
#    'ヤン',
#    'ママ',
#    '格好',
#    '記事',
#    '取材',
#    '来',
#    '記者',
#    '話す',
#    'こと',
#    '激怒',
#    'し',
#    'い',
#    'いう']},
#  {'score': 0.15564645349299866,
#   'token_seq': ['潰れる',
#    '言わ',
#    'れ',
#    'ん',
#    '管理',
#    '人',
#    '交代',
#    'ダメ',
#    '?」「',
#    '財団',
#    '法人',
#    '警察',
#    '直接',
#    '依頼',
#    'す',
#    '警察',
#    '天下り',
#    '団体',
#    '仕事',
#    '振っ',
#    'いる',
#    'よう',
#    '見え',
#    '2',
#    'ちゃん',
#    'ねる',
#    '潰し',
#    'ちゃっ',
#    '小さい',
#    '掲示板',
#    '散らばっ',
#    '余計',
#    '捕まえ',
#    'にくく',
#    'なる',
#    '2',
#    'ちゃん',
#    'ねる',
#    '存続',
#    '求める',
#    '声',
#    '警察',
#    '捜査',
#    '批判',
#    'する',
#    '声',
#    '様々',
#    '意見',
#    '寄せ',
#    'られ',
#    'い']},
#  {'score': 0.15564600413351096,
#   'token_seq': ['最初',
#    '設定',
#    '作っ',
#    'ちゃう',
#    '芸能',
#    '界',
#    'よく',
#    'TV',
#    '大胆',
#    '芸能',
#    '界',
#    '批判',
#    '口',
#    'する']},
#  {'score': 0.15542914144483003,
#   'token_seq': ['ツイッター',
#    'すごい',
#    'やっ',
#    '!',
#    '柏原',
#    '自分',
#    '貫い',
#    '柏原',
#    '賞賛',
#    '声',
#    '多数',
#    '寄せ',
#    'られ',
#    'いる',
#    'AKB',
#    '失礼',
#    '批判',
#    '目立つ',
#    '声優',
#    '花澤',
#    '香菜',
#    'ファン',
#    '有名',
#    'ため',
#    'AKB',
#    '興味',
#    'ない',
#    'の',
#    '仕方',
#    '柏原',
#    '好み',
#    '無視',
#    'し',
#    '質問',
#    'し',
#    '番組',
#    '側',
#    'リサーチ',
#    '不足',
#    '指摘',
#    'する',
#    '声',
#    '一部',
#    '見',
#    'られ']},
#  {'score': 0.15525914590218864, 'token_seq': ['茂木', '健一郎', '氏', 'ツイッターアカウント']},
#  {'score': 0.15514844692451085,
#   'token_seq': ['大塚',
#    '氏',
#    '卒業',
#    '同局',
#    '三宅',
#    '正治',
#    'アナウンサー',
#    '後任',
#    'メイン',
#    'キャスター',
#    'なる',
#    'こと',
#    '報じ',
#    'られ',
#    'い',
#    'やみ',
#    '言う',
#    '女子',
#    'アナ',
#    '馴れ合う',
#    '三宅',
#    '爽やか',
#    '朝',
#    '合わ',
#    '朝',
#    '三宅',
#    '暑苦しい',
#    'メイン',
#    'キャスター',
#    'なれ',
#    '軽部',
#    '笠井',
#    'どん',
#    '信用',
#    '無い',
#    'ん',
#    '後任',
#    '人選',
#    'ミス',
#    '指摘',
#    'する',
#    '声',
#    '相次い']},
#  {'score': 0.1551291365909013,
#   'token_seq': ['エア',
#    '恋愛',
#    '相手',
#    '芸能人',
#    '宅配',
#    '便',
#    '兄さん',
#    'ママ',
#    '友',
#    '夫',
#    'さまざま']},
#  {'score': 0.1550447425822693, 'token_seq': ['問いかけ', 'られ', 'こと']},
#  {'score': 0.15499331286978377,
#   'token_seq': ['箇所',
#    '取り上げ',
#    'ニュース',
#    'ネット',
#    'ユーザー',
#    '間',
#    '波紋',
#    '呼び',
#    '小学生',
#    '中学生',
#    'インターネッツ',
#    '簡単',
#    'エロ',
#    '画像',
#    'エロ',
#    '動画',
#    '見れ',
#    'ちゃう',
#    '方',
#    'やばい',
#    '賛同',
#    'する',
#    '意見',
#    'あっ',
#    '大半',
#    'これ',
#    'し',
#    'てる',
#    '言い',
#    'よう',
#    'ない',
#    '青少年',
#    '健全',
#    '育成',
#    'する',
#    'ため',
#    'する',
#    'こと',
#    'ある',
#    'ん',
#    '怒り',
#    '声',
#    '続出',
#    '女',
#    'レイプ',
#    'する',
#    '小説',
#    '書い',
#    '知事',
#    '言わ',
#    'れ',
#    '石原',
#    '都知事',
#    '批判',
#    'する',
#    '声',
#    '見',
#    'られ']},
#  {'score': 0.15496585038532193,
#   'token_seq': ['漫画',
#    '家',
#    'AKB',
#    '48',
#    'ファン',
#    '知ら',
#    'れる',
#    '小林',
#    '氏',
#    'ブログ',
#    'わし',
#    '今',
#    '前田',
#    '敦子',
#    '名',
#    '推し',
#    'メン',
#    '上げ',
#    'こと',
#    'あり',
#    'し',
#    'フライングゲット',
#    '前奏',
#    '始まる',
#    '否',
#    'すくっ',
#    '立ち',
#    '現れる',
#    '前田',
#    '敦子',
#    '華やかさ',
#    '見る',
#    'たび',
#    'ＡＫＢ',
#    '背負う',
#    'の',
#    '子',
#    '思っ',
#    'い',
#    '複雑',
#    'ファン',
#    '心理',
#    '伝え',
#    'いる']},
#  {'score': 0.15482388291677399,
#   'token_seq': ['内容',
#    'ネット',
#    '掲示板',
#    'お悔やみ',
#    '申し上げ',
#    'これ',
#    'さ',
#    '可哀想',
#    '大沢',
#    '同情',
#    '声',
#    '寄せ',
#    'られ',
#    '子ども',
#    '遺体',
#    'ブログ',
#    '掲載',
#    'する',
#    'の',
#    'いかが',
#    'もの',
#    '大沢',
#    '精神',
#    '的',
#    '参っ',
#    'いる',
#    '思う',
#    '考え',
#    'これ',
#    'やり',
#    'すぎ',
#    '人',
#    '親',
#    'マジ',
#    'わけ',
#    'わから',
#    '家族',
#    'あいだ',
#    '乗り越える',
#    'こと',
#    '大沢',
#    'バッシング',
#    '相次ぐ',
#    '事態',
#    'なり',
#    '現在',
#    '大沢',
#    '子ども',
#    '写真',
#    '削除',
#    'し',
#    'いる']},
#  {'score': 0.1547482332868737,
#   'token_seq': ['昨晩',
#    '以前',
#    '行っ',
#    'こと',
#    'ある',
#    'レストラン',
#    '友達',
#    '行っ',
#    'ん',
#    '注文',
#    'し',
#    '食べ物',
#    '待っ',
#    'いる',
#    '間',
#    '意味',
#    '不明',
#    '生臭い',
#    'モノ',
#    '入っ',
#    '小皿',
#    '出',
#    'き',
#    '悪い',
#    '予感',
#    'し',
#    'もん',
#    '確認',
#    'し',
#    '400',
#    '円',
#    '追加',
#    'さ',
#    'れ',
#    'て',
#    'ん',
#    '書い',
#    'いる']},
#  {'score': 0.15474438576100435,
#   'token_seq': ['番組',
#    '冒頭',
#    '井上',
#    '歳',
#    '女性',
#    'マネージャ',
#    '井上',
#    '肩',
#    '凝っ',
#    'ハッカ',
#    '油',
#    'スプレー',
#    'かけ',
#    'マッサージ',
#    'し',
#    'くれ',
#    '優しい',
#    '思っ',
#    '後ろ',
#    '急',
#    'テイ',
#    'いっ',
#    'ハッカ',
#    '油',
#    '鼻',
#    '下',
#    '塗ら',
#    'れ',
#    '日',
#    '一',
#    '日',
#    '中',
#    '鼻',
#    'スースー',
#    'し',
#    '鼻水',
#    '垂れ',
#    'いる',
#    '感覚',
#    'おそわ',
#    'れ',
#    '可愛らしい',
#    'イタズラ',
#    '紹介',
#    'さ',
#    'れる',
#    'これ',
#    '序の口']},
#  {'score': 0.1547278887883593,
#   'token_seq': ['記事',
#    '受け',
#    'ネット',
#    '掲示板',
#    '人',
#    '記事',
#    '良かっ',
#    '外',
#    '目',
#    '向け',
#    '自分',
#    'たち',
#    '見つめ',
#    '直す',
#    '機会',
#    'なれ',
#    '良い',
#    '通り',
#    '読ん',
#    'おもしろい',
#    '記事',
#    '肯定',
#    '的',
#    '意見',
#    '韓国',
#    '人',
#    '妄想',
#    '言わ',
#    '気持ち',
#    '悪い',
#    '性',
#    '犯罪',
#    '多発',
#    'する',
#    '理由',
#    'わかっ',
#    '毎日',
#    'ネタ',
#    '提供',
#    'し',
#    'くれる',
#    '国',
#    '韓国',
#    '以外',
#    'あり',
#    '得',
#    '韓国',
#    '批判',
#    'さまざま',
#    '書き込み',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.1546496741880754, 'token_seq': ['質問', 'コメント', '寄せ', 'られ', 'おり']},
#  {'score': 0.15460282167965447,
#   'token_seq': ['話題',
#    'なっ',
#    'いる',
#    'CM',
#    '内容',
#    '前田',
#    '敦子',
#    '柏木',
#    '由紀',
#    '篠田',
#    '麻里子',
#    '板野',
#    '友美',
#    'AKB',
#    '48',
#    '主要',
#    'メンバー',
#    '口移し',
#    'ぷっちょ',
#    '渡し',
#    'いく',
#    'もの']},
#  {'score': 0.1545807211437837,
#   'token_seq': ['ネット',
#    '掲示板',
#    '一切',
#    '募金',
#    'し',
#    'おれ',
#    '死角',
#    'なかっ',
#    '震災',
#    'さま',
#    'さま',
#    'スマ',
#    'ホ',
#    '寿司',
#    '消費',
#    'かまわ',
#    'の',
#    'パチンコ',
#    'ダメ',
#    '田舎',
#    '感覚',
#    '狂っ',
#    'てる',
#    '何',
#    '年',
#    'もらえる',
#    'ん',
#    '5',
#    '年',
#    '5',
#    '年',
#    '月',
#    '80',
#    '万',
#    '4800',
#    '万']},
#  {'score': 0.1545359627219089,
#   'token_seq': ['状況',
#    '中',
#    'イデイリー',
#    'コメント',
#    '欄',
#    'これ',
#    '完全',
#    '負け戦',
#    '誤審',
#    'なけれ',
#    '勝てる',
#    '日本',
#    'スペイン',
#    '勝っ',
#    '韓国',
#    'イギリス',
#    '勝て',
#    '言い',
#    '切れ',
#    'カーディフ',
#    'ウェールズ',
#    'ホーム',
#    'アドバンテージ',
#    '弱い',
#    'イギリス',
#    '負け',
#    'いい',
#    '日本',
#    '決勝',
#    '行く',
#    'の',
#    '勘弁',
#    'し',
#    'ほしい',
#    '様々',
#    'コメント',
#    '寄せ',
#    'られ',
#    'いる']},
#  {'score': 0.1545237784420179,
#   'token_seq': ['コメント',
#    '出せ',
#    '書い',
#    'てる',
#    'やつ',
#    'ら',
#    'いっぱい',
#    'い',
#    '結局',
#    'コメント',
#    '出し',
#    'やっ',
#    '批判',
#    'さ',
#    'れる',
#    '松嶋',
#    '叩く',
#    'の',
#    '無理',
#    'ある',
#    '擁護',
#    'する',
#    '声',
#    '中島',
#    '松嶋',
#    '1993',
#    '年',
#    '4',
#    '月',
#    'コンビ',
#    '組み',
#    '長年',
#    '苦楽',
#    'し',
#    'き',
#    'ネット',
#    'ユーザー',
#    '松嶋',
#    'コメント',
#    'し',
#    'いる',
#    '感じ',
#    'られ',
#    'よう']},
#  {'score': 0.15451412117385238,
#   'token_seq': ['韓',
#    '流',
#    'ごり押し',
#    'やめろ',
#    'ネトウヨ',
#    '批判',
#    'さ',
#    'れる',
#    'こと',
#    '多い',
#    'フジテレビ',
#    '番組',
#    '反撃',
#    'なる',
#    'の',
#    '?']},
#  {'score': 0.1544310609385381,
#   'token_seq': ['内容',
#    '興味',
#    '持っ',
#    'ユーザー',
#    '多く',
#    'レジ',
#    '持っ',
#    '行き',
#    'づらい',
#    '女性',
#    '店員',
#    '放尿',
#    'あり',
#    '?',
#    '聞け',
#    '購入',
#    '不安',
#    '書き込ん',
#    'おり',
#    '複雑',
#    '消費',
#    '者',
#    '心理',
#    'のぞかせ',
#    'い']},
#  {'score': 0.1544204964157505,
#   'token_seq': ['4',
#    '組',
#    'ゲスト',
#    '中',
#    'ネット',
#    '掲示板',
#    '反響',
#    '大きかっ',
#    'の',
#    '有吉',
#    '毒舌',
#    '知ら',
#    'れる',
#    '有吉',
#    'ホスト',
#    '陣',
#    '様々',
#    '質問',
#    'ぶつける',
#    '中',
#    '話題',
#    'なっ',
#    'の',
#    '絡み',
#    'づらい',
#    '大物',
#    '誰',
#    '?」',
#    'もの']},
#  {'score': 0.15435130105709582,
#   'token_seq': ['女性',
#    '教授',
#    '発言',
#    'ネット',
#    '掲示板',
#    '圧迫',
#    '面接',
#    '面接',
#    '"',
#    'あんた',
#    '"',
#    '批判',
#    '殺到',
#    '中',
#    '遠回し',
#    '誘っ',
#    'てる',
#    'の',
#    '?」「',
#    'これ',
#    '新手',
#    'プレイ',
#    '女性',
#    '教授',
#    '発言',
#    '性的',
#    '意味合い',
#    '揶揄',
#    'する',
#    'ユーザー',
#    '見',
#    'られ']},
#  ...]

# %%
model.wv.similar_by_word('嬉しい')
# Out:
# [('うれしい', 0.9171843528747559),
#  ('嬉しかっ', 0.8691217303276062),
#  ('すごい', 0.8576909899711609),
#  ('やれる', 0.8458874821662903),
#  ('ありがたい', 0.8440902829170227),
#  ('楽しかっ', 0.8345097899436951),
#  ('恥ずかしい', 0.8334256410598755),
#  ('申し訳ない', 0.8254172205924988),
#  ('すごく', 0.8196461200714111),
#  ('皆さん', 0.8161286115646362)]

# %%
model.wv.similar_by_word('いい')
# Out:
# [('うまい', 0.793982982635498),
#  ('言う', 0.7922905683517456),
#  ('ありがたい', 0.7680160403251648),
#  ('言い', 0.7668641805648804),
#  ('くくる', 0.763872504234314),
#  ('困る', 0.7616062164306641),
#  ('云う', 0.7576260566711426),
#  ('なあ', 0.7515909075737),
#  ('いって', 0.7459474205970764),
#  ('言い放つ', 0.732398509979248)]

# %%
model.wv.similar_by_word('厳しい')
# Out:
# [('厳しく', 0.7486790418624878),
#  ('不安', 0.7111629247665405),
#  ('悪さ', 0.7081772685050964),
#  ('極度', 0.678291380405426),
#  ('それなり', 0.65279221534729),
#  ('厳しかっ', 0.648469865322113),
#  ('重い', 0.6451793909072876),
#  ('苦しい', 0.6360158920288086),
#  ('悪い', 0.635636568069458),
#  ('風紀', 0.6352398991584778)]
